# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # SQL Exam
# © ExploreAI Academy

# %% [markdown]
# ## Instructions to students
#
# This challenge is designed to determine how much you have learned so far and will test your knowledge on SQL.
#
# The answers for this challenge should be selected on Athena for each corresponding multiple-choice question. The questions are included in this notebook and are numbered according to the Athena questions. The options for each question have also been included.
#
# Do not add or remove cells in this notebook. Do not edit or remove the `%%sql` comment as it is required to run each cell.
#
# **_Good luck!_**

# %% [markdown]
# ## Honour code
#
# I, YOUR NAME YOUR SURNAME, confirm – by submitting this document – that the solutions in this notebook are a result of my own work and that I abide by the EDSA honour code (https://drive.google.com/file/d/1QDCjGZJ8-FmJE3bZdIQNwnJyQKPhHZBn/view?usp=sharing).
#
# Non-compliance with the honour code constitutes a material breach of contract.

# %% [markdown]
# ## The TMDb database
#
# In this supplementary exam, you will be exploring [The Movie Database](https://www.themoviedb.org/) – an online movie and TV show database that houses some of the most popular movies and TV shows at your fingertips. The TMDb database supports 39 official languages used in over 180 countries daily and dates back all the way to 2008.
#
#
# <img src="https://github.com/Explore-AI/Pictures/blob/master/sql_tmdb.jpg?raw=true" width=80%/>
#
#
# Below is an Entity Relationship Diagram (ERD) of the TMDb database:
#
# <img src="https://github.com/Explore-AI/Pictures/blob/master/TMDB_ER_diagram.png?raw=true" width=70%/>
#
# As can be seen from the ERD, the TMDb database consists of `12 tables` containing information about movies, cast, genre, and so much more.
#
# Let's get started!

# %% [markdown]
# ## Loading the database
#
# Before you begin, you need to prepare your SQL environment.  You can do this by loading the magic command `%load_ext sql`.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# Next, go ahead and load your database. To do this, you will need to ensure you have downloaded the `TMDB.db` sqlite file from Athena and have stored it in a known location.

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql sqlite:///TMDB-a-4006.db
# Out:
# 'Connected: @TMDB-a-4006.db'

# %% [markdown]
# If the above line didn't throw out any errors, then you should be good to go. Good luck with the exam!

# %% [markdown]
# ## Questions on SQL
#
# Use the given cell below each question to execute your SQL queries to find the correct input from the options provided. Your solution should match one of the multiple-choice questions on Athena.

# %% [markdown]
# ### Question 1
#
# Who won the Oscar for “Actor in a Leading Role” in  2015?
#
# (Hint: The winner is indicated as '1.0'.)
#
# **Options:**
#
#   - Micheal Fassbender
#   - Natalie Portman
#   - Leonardo DiCaprio
#   - Eddie Redmayne

# %%
# %%sql
# SELECT
#     *
# FROM
#     oscars
# WHERE
#     year = '2015'
# AND award = 'Actor in a Leading Role'
# AND winner = '1.0'
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [('2015', 'Actor in a Leading Role', '1.0', 'Leonardo DiCaprio', 'The Revenant')]

# %% [markdown]
# ### Question 2
#
# What query will produce the ten oldest movies in the database?
#
# **Options:**
#
#  - SELECT TOP(10) * FROM movies WHERE release_date ORDER BY release_date ASC
#
#  - SELECT  * FROM movies WHERE release_date IS NOT NULL ORDER BY release_date ASC LIMIT 10
#
#  - SELECT * FROM movies WHERE release_date IS NOT NULL ORDER BY release_date DESC LIMIT 10
#
#  -  SELECT * FROM movies WHERE release_date IS NULL ORDER BY release_date DESC LIMIT 10

# %%
# %%sql
# SELECT  * FROM movies WHERE release_date IS NOT NULL ORDER BY release_date ASC LIMIT 10
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [(3059, 'Intolerance', '1916-09-04 00:00:00.000000', 385907, None, 'en', 'Intolerance', 'The story of a poor young woman, separated by prejudice from her husband and baby, is interwoven with tales of intolerance from throughout history.', 3.232447, 8394751.0, 197.0, 'Released', 'The Cruel Hand of Intolerance', 7.4, 60),
#  (3060, 'The Big Parade', '1925-11-05 00:00:00.000000', 245000, None, 'en', 'The Big Parade', "The story of an idle rich boy who joins the US Army's Rainbow Division and is sent to France to fight in World War I, becomes friends with two working class men, experiences the horrors of trench warfare, and finds love with a French girl.", 0.785744, 22000000.0, 151.0, 'Released', None, 7.0, 21),
#  (19, 'Metropolis', '1927-01-10 00:00:00.000000', 92620000, None, 'de', 'Metropolis', "In a futuristic city sharply divided between the working class and the city planners, the son of the city's mastermind falls in love with a working class prophet who predicts the coming of a savior to mediate their differences.", 32.351527, 650422.0, 153.0, 'Released', 'There can be no understanding between the hands and the brain unless the heart acts as mediator.', 8.0, 657),
#  (905, "Pandora's Box", '1929-01-30 00:00:00.000000', 0, None, 'de', 'Die Bnchse der Pandora', 'The rise and inevitable fall of an amoral but naive young woman whose insouciant eroticism inspires lust and violence in those around her.', 1.824184, 0.0, 109.0, 'Released', None, 7.6, 45),
#  (65203, 'The Broadway Melody', '1929-02-08 00:00:00.000000', 379000, None, 'en', 'The Broadway Melody', "Harriet and Queenie Mahoney, a vaudeville act, come to Broadway, where their friend Eddie Kerns needs them for his number in one of Francis Zanfield' ... (195 characters truncated) ... eenie recognizes, that she is for Jock nothing more than a toy, and it also takes a while till Harriet recognizes, that Eddie is in love with Queenie", 0.968865, 4358000.0, 100.0, 'Released', "The pulsating drama of Broadway's bared heart speaks and sings with a voice to stir your soul!", 5.0, 19),
#  (22301, "Hell's Angels", '1930-11-15 00:00:00.000000', 3950000, None, 'en', "Hell's Angels", "Two brothers attending Oxford enlist with the Royal Flying Corps when World War I breaks out. Roy and Monte Rutledge have very different personalitie ... (576 characters truncated) ... t a strategic German munitions facility is a booming success, but with a squadron of fighters bearing down on them afterwards, escape seems unlikely.", 8.484123, 8000000.0, 127.0, 'Released', "Howard Hughes' Thrilling Multi-Million Dollar Air Spectacle", 6.1, 19),
#  (22649, 'A Farewell to Arms', '1932-12-08 00:00:00.000000', 4, None, 'en', 'A Farewell to Arms', "British nurse Catherine Barkley (Helen Hayes) and American Lieutenant Frederic Henry (Gary Cooper) fall in love during the First World War in Italy.  ... (105 characters truncated) ... the war rages on. Academy Awards winner for Best Cinematography and for Best Sound, Recording. Nominated for Best Picture and for Best Art Direction.", 1.199451, 25.0, 89.0, 'Released', 'Every woman who has loved will understand', 6.2, 28),
#  (3062, '42nd Street', '1933-02-02 00:00:00.000000', 439000, None, 'en', '42nd Street', 'A producer puts on what may be his last Broadway show, and at the last moment a chorus girl has to replace the star.', 1.933366, 2281000.0, 89.0, 'Released', None, 6.1, 37),
#  (43595, 'She Done Him Wrong', '1933-02-09 00:00:00.000000', 200000, None, 'en', 'She Done Him Wrong', '"New York singer and nightclub owner Lady Lou has more men friends than you can imagine. Unfortunately one of them is a vicious criminal who\'s escap ... (52 characters truncated) ... ing she hasn\'t exactly been faithful in his absence. Help is at hand in the form of young Captain Cummings a local temperance league leader though."', 0.622752, 2200000.0, 66.0, 'Released', "Mae West gives a 'Hot Time' to the nation!", 5.1, 27),
#  (3078, 'It Happened One Night', '1934-02-22 00:00:00.000000', 325000, None, 'en', 'It Happened One Night', "Ellie Andrews has just tied the knot with society aviator King Westley when she is whisked away to her father's yacht and out of King's clutches. Ell ... (233 characters truncated) ... ts her back to her husband, or he'll blow the whistle on Ellie to her father. Either way, Peter gets what he wants... a really juicy newspaper story!", 11.871424, 4500000.0, 105.0, 'Released', 'TOGETHER... for the first time', 7.7, 275)]

# %% [markdown]
# ### Question 3
#
# How many unique awards are there in the Oscars table?
#
# **Options:**
#  - 141
#  - 53
#  - 80
#  - 114

# %%
# %%sql
# SELECT
#     COUNT(DISTINCT(award)) as unique_awards_in_Oscars
# FROM
#     oscars;
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [(114,)]

# %% [markdown]
# ### Question 4
#
# How many movies are there that contain the word “Spider” within their title?
#
# **Options:**
#  - 0
#  - 5
#  - 1
#  - 9

# %%
# %%sql
# SELECT
#     COUNT(*) as spider_contained_name_movies
# FROM
#     movies
# WHERE
#     title LIKE '%Spider%'
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [(9,)]

# %% [markdown]
# ### Question 5
#
# How many movies are there that are both in the "Thriller" genre and contain the word “love” anywhere in the keywords?
#
#
# **Options:**
#  - 48
#  - 38
#  - 14
#  - 1

# %%
# %%sql
# SELECT
#     COUNT(distinct(movies.movie_id))
# FROM
#     movies
#  JOIN genremap ON genremap.movie_id = movies.movie_id
#  JOIN genres ON genres.genre_id = genremap.genre_id
#  JOIN keywordmap ON keywordmap.movie_id = movies.movie_id
#  JOIN keywords ON keywords.keyword_id = keywordmap.keyword_id
#
# WHERE
#     genres.genre_name = 'Thriller' AND keywords.keyword_name LIKE '%love%'
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [(48,)]

# %% [markdown]
# ### Question 6
#
# How many movies are there that were released between 1 August 2006 ('2006-08-01') and 1 October 2009 ('2009-10-01') that have a popularity score of more than 40 and a budget of less than 50 000 000?
#
#
# **Options:**
#
#  - 29
#  - 23
#  - 28
#  - 35

# %%
# %%sql
#
# SELECT
#     count(title)
# FROM
#     movies
# WHERE
#     date(release_date) BETWEEN '2006-08-01' AND '2009-10-01'
# AND popularity > 40
# AND budget < 50000000;
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [(29,)]

# %% [markdown]
# ### Question 7
#
# How many unique characters has "Vin Diesel" played so far in the database?
#
# **Options:**
#  - 24
#  - 19
#  - 18
#  - 16

# %%
# %%sql
#
# SELECT
#     movies.title,
#     actors.actor_name
# FROM movies
# JOIN casts ON casts.movie_id = movies.movie_id
# JOIN actors ON actors.actor_id = casts.actor_id
# WHERE actor_name = 'Vin Diesel';
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [('The Fifth Element', 'Vin Diesel'),
#  ('Saving Private Ryan', 'Vin Diesel'),
#  ('Pitch Black', 'Vin Diesel'),
#  ('The Chronicles of Riddick', 'Vin Diesel'),
#  ('xXx', 'Vin Diesel'),
#  ('Knockaround Guys', 'Vin Diesel'),
#  ('A Man Apart', 'Vin Diesel'),
#  ('Babylon A.D.', 'Vin Diesel'),
#  ('The Fast and the Furious: Tokyo Drift', 'Vin Diesel'),
#  ('The Fast and the Furious', 'Vin Diesel'),
#  ('Find Me Guilty', 'Vin Diesel'),
#  ('The Pacifier', 'Vin Diesel'),
#  ('The Iron Giant', 'Vin Diesel'),
#  ('Boiler Room', 'Vin Diesel'),
#  ('Fast Five', 'Vin Diesel'),
#  ('Riddick', 'Vin Diesel'),
#  ('Guardians of the Galaxy', 'Vin Diesel'),
#  ('Furious 7', 'Vin Diesel'),
#  ('The Last Witch Hunter', 'Vin Diesel')]

# %% [markdown]
# ### Question 8
#
# What are the genres of the movie “The Royal Tenenbaums”?
#
#
# **Options:**
#  - Action, Romance
#  - Drama, Comedy
#  - Crime, Thriller
#  - Drama, Romance

# %%
# %%sql
#
# SELECT
#     m.title,
#     m.movie_id,
#     gm.genre_id,
#     g.genre_name
# FROM
#     movies as m
# JOIN genremap as gm ON gm.movie_id = m.movie_id
# JOIN genres as g ON g.genre_id = gm.genre_id
# WHERE title = 'The Royal Tenenbaums'
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [('The Royal Tenenbaums', 9428, 18, 'Drama'),
#  ('The Royal Tenenbaums', 9428, 35, 'Comedy')]

# %% [markdown]
# ### Question 9
#
# What are the three production companies that have the highest movie popularity score on average, as recorded within the database?
#
#
# **Options:**
#
#  - MCL Films S.A., Turner Pictures, and George Stevens Productions
#  - The Donners' Company, Bulletproof Cupid, and Kinberg Genre
#  - Bulletproof Cupid, The Donners' Company, and MCL Films S.A
#  - B.Sting Entertainment, Illumination Pictures, and Aztec Musique

# %%
# %%sql
#
# SELECT
#     pcom.production_company_name,
#     avg(m.popularity) as avg_pop
# FROM
#     movies as m
# JOIN productioncompanymap as pmap ON pmap.movie_id = m.movie_id
# JOIN productioncompanies as pcom ON pcom.production_company_id = pmap.production_company_id
# GROUP BY production_company_name
# ORDER BY avg_pop DESC
# LIMIT 3;
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [("The Donners' Company", 514.569956),
#  ('Bulletproof Cupid', 481.098624),
#  ('Kinberg Genre', 326.92099900000005)]

# %% [markdown]
# ### Question 10
#
# How many female actors (i.e. gender = 1) have a name that starts with the letter "N"?
#
#
# **Options:**
#
#  - 0
#  - 355
#  - 7335
#  - 1949

# %%
# %%sql
# SELECT
#     count(actor_name)
# FROM
#     actors
# WHERE gender = 1 AND actor_name LIKE 'N%'
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [(355,)]

# %% [markdown]
# ### Question 11
#
# Which genre has, on average, the lowest movie popularity score?
#
#
# **Options:**
#
#  - Science Fiction
#  - Animation
#  - Documentary
#  - Foreign

# %%
# %%sql
# SELECT
#     g.genre_name,
#     avg(m.popularity) as avg_pop
# FROM
#     genres as g
# JOIN genremap as gm ON gm.genre_id = g.genre_id
# JOIN movies as m ON m.movie_id = gm.movie_id
# GROUP BY g.genre_name
# ORDER BY avg_pop ASC
# LIMIT 1;
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [('Foreign', 0.686786794117647)]

# %% [markdown]
# ### Question 12
#
# Which award category has the highest number of actor nominations (actors can be male or female)? (Hint: `Oscars.name` contains both actors' names and film names.)
#
# **Options:**
#
# - Special Achievement Award
# - Actor in a Supporting Role
# - Actress in a Supporting Role
# - Best Picture

# %%
# %%sql
# SELECT
#     *
# FROM
#     oscars
# WHERE award IN ('Special Achievement Award', 'Actor in a Supporting Role', 'Actress in a Supporting Role', 'Best Picture')
# LIMIT 10;
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [('1936', 'Actor in a Supporting Role', None, 'Mischa Auer', 'My Man Godfrey'),
#  ('1936', 'Actor in a Supporting Role', '1.0', 'Walter Brennan', 'Come and Get It'),
#  ('1936', 'Actor in a Supporting Role', None, 'Stuart Erwin', 'Pigskin Parade'),
#  ('1936', 'Actor in a Supporting Role', None, 'Basil Rathbone', 'Romeo and Juliet'),
#  ('1936', 'Actor in a Supporting Role', None, 'Akim Tamiroff', 'The General Died at Dawn'),
#  ('1936', 'Actress in a Supporting Role', None, 'Beulah Bondi', 'The Gorgeous Hussy'),
#  ('1936', 'Actress in a Supporting Role', None, 'Alice Brady', 'My Man Godfrey'),
#  ('1936', 'Actress in a Supporting Role', None, 'Bonita Granville', 'These Three'),
#  ('1936', 'Actress in a Supporting Role', None, 'Maria Ouspenskaya', 'Dodsworth'),
#  ('1936', 'Actress in a Supporting Role', '1.0', 'Gale Sondergaard', 'Anthony Adverse'),
#  ('1937', 'Actor in a Supporting Role', None, 'Ralph Bellamy', 'The Awful Truth'),
#  ('1937', 'Actor in a Supporting Role', None, 'Thomas Mitchell', 'The Hurricane'),
#  ('1937', 'Actor in a Supporting Role', '1.0', 'Joseph Schildkraut', 'The Life of Emile Zola'),
#  ('1937', 'Actor in a Supporting Role', None, 'H. B. Warner', 'Lost Horizon'),
#  ('1937', 'Actor in a Supporting Role', None, 'Roland Young', 'Topper'),
#  ('1937', 'Actress in a Supporting Role', '1.0', 'Alice Brady', 'In Old Chicago'),
#  ('1937', 'Actress in a Supporting Role', None, 'Andrea Leeds', 'Stage Door'),
#  ('1937', 'Actress in a Supporting Role', None, 'Anne Shirley', 'Stella Dallas'),
#  ('1937', 'Actress in a Supporting Role', None, 'Claire Trevor', 'Dead End'),
#  ('1937', 'Actress in a Supporting Role', None, 'Dame May Whitty', 'Night Must Fall'),
#  ('1938', 'Actor in a Supporting Role', '1.0', 'Walter Brennan', 'Kentucky'),
#  ('1938', 'Actor in a Supporting Role', None, 'John Garfield', 'Four Daughters'),
#  ('1938', 'Actor in a Supporting Role', None, 'Gene Lockhart', 'Algiers'),
#  ('1938', 'Actor in a Supporting Role', None, 'Robert Morley', 'Marie Antoinette'),
#  ('1938', 'Actor in a Supporting Role', None, 'Basil Rathbone', 'If I Were King'),
#  ('1938', 'Actress in a Supporting Role', '1.0', 'Fay Bainter', 'Jezebel'),
#  ('1938', 'Actress in a Supporting Role', None, 'Beulah Bondi', 'Of Human Hearts'),
#  ('1938', 'Actress in a Supporting Role', None, 'Billie Burke', 'Merrily We Live'),
#  ('1938', 'Actress in a Supporting Role', None, 'Spring Byington', "You Can't Take It with You"),
#  ('1938', 'Actress in a Supporting Role', None, 'Miliza Korjus', 'The Great Waltz'),
#  ('1939', 'Actor in a Supporting Role', None, 'Brian Aherne', 'Juarez'),
#  ('1939', 'Actor in a Supporting Role', None, 'Harry Carey', 'Mr. Smith Goes to Washington'),
#  ('1939', 'Actor in a Supporting Role', None, 'Brian Donlevy', 'Beau Geste'),
#  ('1939', 'Actor in a Supporting Role', '1.0', 'Thomas Mitchell', 'Stagecoach'),
#  ('1939', 'Actor in a Supporting Role', None, 'Claude Rains', 'Mr. Smith Goes to Washington'),
#  ('1939', 'Actress in a Supporting Role', None, 'Olivia de Havilland', 'Gone with the Wind'),
#  ('1939', 'Actress in a Supporting Role', None, 'Geraldine Fitzgerald', 'Wuthering Heights'),
#  ('1939', 'Actress in a Supporting Role', '1.0', 'Hattie McDaniel', 'Gone with the Wind'),
#  ('1939', 'Actress in a Supporting Role', None, 'Edna May Oliver', 'Drums along the Mohawk'),
#  ('1939', 'Actress in a Supporting Role', None, 'Maria Ouspenskaya', 'Love Affair'),
#  ('1940', 'Actor in a Supporting Role', None, 'Albert Basserman', 'Foreign Correspondent'),
#  ('1940', 'Actor in a Supporting Role', '1.0', 'Walter Brennan', 'The Westerner'),
#  ('1940', 'Actor in a Supporting Role', None, 'William Gargan', 'They Knew What They Wanted'),
#  ('1940', 'Actor in a Supporting Role', None, 'Jack Oakie', 'The Great Dictator'),
#  ('1940', 'Actor in a Supporting Role', None, 'James Stephenson', 'The Letter'),
#  ('1940', 'Actress in a Supporting Role', None, 'Judith Anderson', 'Rebecca'),
#  ('1940', 'Actress in a Supporting Role', '1.0', 'Jane Darwell', 'The Grapes of Wrath'),
#  ('1940', 'Actress in a Supporting Role', None, 'Ruth Hussey', 'The Philadelphia Story'),
#  ('1940', 'Actress in a Supporting Role', None, "Barbara O'Neil", 'All This, and Heaven Too'),
#  ('1940', 'Actress in a Supporting Role', None, 'Marjorie Rambeau', 'Primrose Path'),
#  ('1941', 'Actor in a Supporting Role', None, 'Walter Brennan', 'Sergeant York'),
#  ('1941', 'Actor in a Supporting Role', None, 'Charles Coburn', 'The Devil and Miss Jones'),
#  ('1941', 'Actor in a Supporting Role', '1.0', 'Donald Crisp', 'How Green Was My Valley'),
#  ('1941', 'Actor in a Supporting Role', None, 'James Gleason', 'Here Comes Mr. Jordan'),
#  ('1941', 'Actor in a Supporting Role', None, 'Sydney Greenstreet', 'The Maltese Falcon'),
#  ('1941', 'Actress in a Supporting Role', None, 'Sara Allgood', 'How Green Was My Valley'),
#  ('1941', 'Actress in a Supporting Role', '1.0', 'Mary Astor', 'The Great Lie'),
#  ('1941', 'Actress in a Supporting Role', None, 'Patricia Collinge', 'The Little Foxes'),
#  ('1941', 'Actress in a Supporting Role', None, 'Teresa Wright', 'The Little Foxes'),
#  ('1941', 'Actress in a Supporting Role', None, 'Margaret Wycherly', 'Sergeant York'),
#  ('1942', 'Actor in a Supporting Role', None, 'William Bendix', 'Wake Island'),
#  ('1942', 'Actor in a Supporting Role', '1.0', 'Van Heflin', 'Johnny Eager'),
#  ('1942', 'Actor in a Supporting Role', None, 'Walter Huston', 'Yankee Doodle Dandy'),
#  ('1942', 'Actor in a Supporting Role', None, 'Frank Morgan', 'Tortilla Flat'),
#  ('1942', 'Actor in a Supporting Role', None, 'Henry Travers', 'Mrs. Miniver'),
#  ('1942', 'Actress in a Supporting Role', None, 'Gladys Cooper', 'Now, Voyager'),
#  ('1942', 'Actress in a Supporting Role', None, 'Agnes Moorehead', 'The Magnificent Ambersons'),
#  ('1942', 'Actress in a Supporting Role', None, 'Susan Peters', 'Random Harvest'),
#  ('1942', 'Actress in a Supporting Role', None, 'Dame May Whitty', 'Mrs. Miniver'),
#  ('1942', 'Actress in a Supporting Role', '1.0', 'Teresa Wright', 'Mrs. Miniver'),
#  ('1943', 'Actor in a Supporting Role', None, 'Charles Bickford', 'The Song of Bernadette'),
#  ('1943', 'Actor in a Supporting Role', '1.0', 'Charles Coburn', 'The More the Merrier'),
#  ('1943', 'Actor in a Supporting Role', None, 'J. Carrol Naish', 'Sahara'),
#  ('1943', 'Actor in a Supporting Role', None, 'Claude Rains', 'Casablanca'),
#  ('1943', 'Actor in a Supporting Role', None, 'Akim Tamiroff', 'For Whom the Bell Tolls'),
#  ('1943', 'Actress in a Supporting Role', None, 'Gladys Cooper', 'The Song of Bernadette'),
#  ('1943', 'Actress in a Supporting Role', None, 'Paulette Goddard', 'So Proudly We Hail!'),
#  ('1943', 'Actress in a Supporting Role', '1.0', 'Katina Paxinou', 'For Whom the Bell Tolls'),
#  ('1943', 'Actress in a Supporting Role', None, 'Anne Revere', 'The Song of Bernadette'),
#  ('1943', 'Actress in a Supporting Role', None, 'Lucile Watson', 'Watch on the Rhine'),
#  ('1944', 'Actor in a Supporting Role', None, 'Hume Cronyn', 'The Seventh Cross'),
#  ('1944', 'Actor in a Supporting Role', '1.0', 'Barry Fitzgerald', 'Going My Way'),
#  ('1944', 'Actor in a Supporting Role', None, 'Claude Rains', 'Mr. Skeffington'),
#  ('1944', 'Actor in a Supporting Role', None, 'Clifton Webb', 'Laura'),
#  ('1944', 'Actor in a Supporting Role', None, 'Monty Woolley', 'Since You Went Away'),
#  ('1944', 'Actress in a Supporting Role', '1.0', 'Ethel Barrymore', 'None but the Lonely Heart'),
#  ('1944', 'Actress in a Supporting Role', None, 'Jennifer Jones', 'Since You Went Away'),
#  ('1944', 'Actress in a Supporting Role', None, 'Angela Lansbury', 'Gaslight'),
#  ('1944', 'Actress in a Supporting Role', None, 'Aline MacMahon', 'Dragon Seed'),
#  ('1944', 'Actress in a Supporting Role', None, 'Agnes Moorehead', 'Mrs. Parkington'),
#  ('1945', 'Actor in a Supporting Role', None, 'Michael Chekhov', 'Spellbound'),
#  ('1945', 'Actor in a Supporting Role', None, 'John Dall', 'The Corn Is Green'),
#  ('1945', 'Actor in a Supporting Role', '1.0', 'James Dunn', 'A Tree Grows in Brooklyn'),
#  ('1945', 'Actor in a Supporting Role', None, 'Robert Mitchum', 'G. I. Joe'),
#  ('1945', 'Actor in a Supporting Role', None, 'J. Carrol Naish', 'A Medal for Benny'),
#  ('1945', 'Actress in a Supporting Role', None, 'Eve Arden', 'Mildred Pierce'),
#  ('1945', 'Actress in a Supporting Role', None, 'Ann Blyth', 'Mildred Pierce'),
#  ('1945', 'Actress in a Supporting Role', None, 'Angela Lansbury', 'The Picture of Dorian Gray'),
#  ('1945', 'Actress in a Supporting Role', None, 'Joan Lorring', 'The Corn Is Green'),
#  ('1945', 'Actress in a Supporting Role', '1.0', 'Anne Revere', 'National Velvet'),
#  ('1946', 'Actor in a Supporting Role', None, 'Charles Coburn', 'The Green Years'),
#  ('1946', 'Actor in a Supporting Role', None, 'William Demarest', 'The Jolson Story'),
#  ('1946', 'Actor in a Supporting Role', None, 'Claude Rains', 'Notorious'),
#  ('1946', 'Actor in a Supporting Role', '1.0', 'Harold Russell', 'The Best Years of Our Lives'),
#  ('1946', 'Actor in a Supporting Role', None, 'Clifton Webb', "The Razor's Edge"),
#  ('1946', 'Actress in a Supporting Role', None, 'Ethel Barrymore', 'The Spiral Staircase'),
#  ('1946', 'Actress in a Supporting Role', '1.0', 'Anne Baxter', "The Razor's Edge"),
#  ('1946', 'Actress in a Supporting Role', None, 'Lillian Gish', 'Duel in the Sun'),
#  ('1946', 'Actress in a Supporting Role', None, 'Flora Robson', 'Saratoga Trunk'),
#  ('1946', 'Actress in a Supporting Role', None, 'Gale Sondergaard', 'Anna and the King of Siam'),
#  ('1947', 'Actor in a Supporting Role', None, 'Charles Bickford', "The Farmer's Daughter"),
#  ('1947', 'Actor in a Supporting Role', None, 'Thomas Gomez', 'Ride the Pink Horse'),
#  ('1947', 'Actor in a Supporting Role', '1.0', 'Edmund Gwenn', 'Miracle on 34th Street'),
#  ('1947', 'Actor in a Supporting Role', None, 'Robert Ryan', 'Crossfire'),
#  ('1947', 'Actor in a Supporting Role', None, 'Richard Widmark', 'Kiss of Death'),
#  ('1947', 'Actress in a Supporting Role', None, 'Ethel Barrymore', 'The Paradine Case'),
#  ('1947', 'Actress in a Supporting Role', None, 'Gloria Grahame', 'Crossfire'),
#  ('1947', 'Actress in a Supporting Role', '1.0', 'Celeste Holm', "Gentleman's Agreement"),
#  ('1947', 'Actress in a Supporting Role', None, 'Marjorie Main', 'The Egg and I'),
#  ('1947', 'Actress in a Supporting Role', None, 'Anne Revere', "Gentleman's Agreement"),
#  ('1948', 'Actor in a Supporting Role', None, 'Charles Bickford', 'Johnny Belinda'),
#  ('1948', 'Actor in a Supporting Role', None, 'Jos+¬ Ferrer', 'Joan of Arc'),
#  ('1948', 'Actor in a Supporting Role', None, 'Oscar Homolka', 'I Remember Mama'),
#  ('1948', 'Actor in a Supporting Role', '1.0', 'Walter Huston', 'The Treasure of the Sierra Madre'),
#  ('1948', 'Actor in a Supporting Role', None, 'Cecil Kellaway', 'The Luck of the Irish'),
#  ('1948', 'Actress in a Supporting Role', None, 'Barbara Bel Geddes', 'I Remember Mama'),
#  ('1948', 'Actress in a Supporting Role', None, 'Ellen Corby', 'I Remember Mama'),
#  ('1948', 'Actress in a Supporting Role', None, 'Agnes Moorehead', 'Johnny Belinda'),
#  ('1948', 'Actress in a Supporting Role', None, 'Jean Simmons', 'Hamlet'),
#  ('1948', 'Actress in a Supporting Role', '1.0', 'Claire Trevor', 'Key Largo'),
#  ('1949', 'Actor in a Supporting Role', None, 'John Ireland', "All the King's Men"),
#  ('1949', 'Actor in a Supporting Role', '1.0', 'Dean Jagger', "Twelve O'Clock High"),
#  ('1949', 'Actor in a Supporting Role', None, 'Arthur Kennedy', 'Champion'),
#  ('1949', 'Actor in a Supporting Role', None, 'Ralph Richardson', 'The Heiress'),
#  ('1949', 'Actor in a Supporting Role', None, 'James Whitmore', 'Battleground'),
#  ('1949', 'Actress in a Supporting Role', None, 'Ethel Barrymore', 'Pinky'),
#  ('1949', 'Actress in a Supporting Role', None, 'Celeste Holm', 'Come to the Stable'),
#  ('1949', 'Actress in a Supporting Role', None, 'Elsa Lanchester', 'Come to the Stable'),
#  ('1949', 'Actress in a Supporting Role', '1.0', 'Mercedes McCambridge', "All the King's Men"),
#  ('1949', 'Actress in a Supporting Role', None, 'Ethel Waters', 'Pinky'),
#  ('1950', 'Actor in a Supporting Role', None, 'Jeff Chandler', 'Broken Arrow'),
#  ('1950', 'Actor in a Supporting Role', None, 'Edmund Gwenn', 'Mister 880'),
#  ('1950', 'Actor in a Supporting Role', None, 'Sam Jaffe', 'The Asphalt Jungle'),
#  ('1950', 'Actor in a Supporting Role', '1.0', 'George Sanders', 'All about Eve'),
#  ('1950', 'Actor in a Supporting Role', None, 'Erich von Stroheim', 'Sunset Blvd.'),
#  ('1950', 'Actress in a Supporting Role', None, 'Hope Emerson', 'Caged'),
#  ('1950', 'Actress in a Supporting Role', None, 'Celeste Holm', 'All about Eve'),
#  ('1950', 'Actress in a Supporting Role', '1.0', 'Josephine Hull', 'Harvey'),
#  ('1950', 'Actress in a Supporting Role', None, 'Nancy Olson', 'Sunset Blvd.'),
#  ('1950', 'Actress in a Supporting Role', None, 'Thelma Ritter', 'All about Eve'),
#  ('1951', 'Actor in a Supporting Role', None, 'Leo Genn', 'Quo Vadis'),
#  ('1951', 'Actor in a Supporting Role', None, 'Kevin McCarthy', 'Death of a Salesman'),
#  ('1951', 'Actor in a Supporting Role', '1.0', 'Karl Malden', 'A Streetcar Named Desire'),
#  ('1951', 'Actor in a Supporting Role', None, 'Peter Ustinov', 'Quo Vadis'),
#  ('1951', 'Actor in a Supporting Role', None, 'Gig Young', 'Come Fill the Cup'),
#  ('1951', 'Actress in a Supporting Role', None, 'Joan Blondell', 'The Blue Veil'),
#  ('1951', 'Actress in a Supporting Role', None, 'Mildred Dunnock', 'Death of a Salesman'),
#  ('1951', 'Actress in a Supporting Role', None, 'Lee Grant', 'Detective Story'),
#  ('1951', 'Actress in a Supporting Role', '1.0', 'Kim Hunter', 'A Streetcar Named Desire'),
#  ('1951', 'Actress in a Supporting Role', None, 'Thelma Ritter', 'The Mating Season'),
#  ('1952', 'Actor in a Supporting Role', None, 'Richard Burton', 'My Cousin Rachel'),
#  ('1952', 'Actor in a Supporting Role', None, 'Arthur Hunnicutt', 'The Big Sky'),
#  ('1952', 'Actor in a Supporting Role', None, 'Victor McLaglen', 'The Quiet Man'),
#  ('1952', 'Actor in a Supporting Role', None, 'Jack Palance', 'Sudden Fear'),
#  ('1952', 'Actor in a Supporting Role', '1.0', 'Anthony Quinn', 'Viva Zapata!'),
#  ('1952', 'Actress in a Supporting Role', '1.0', 'Gloria Grahame', 'The Bad and the Beautiful'),
#  ('1952', 'Actress in a Supporting Role', None, 'Jean Hagen', "Singin' in the Rain"),
#  ('1952', 'Actress in a Supporting Role', None, 'Colette Marchand', 'Moulin Rouge'),
#  ('1952', 'Actress in a Supporting Role', None, 'Terry Moore', 'Come Back, Little Sheba'),
#  ('1952', 'Actress in a Supporting Role', None, 'Thelma Ritter', 'With a Song in My Heart'),
#  ('1953', 'Actor in a Supporting Role', None, 'Eddie Albert', 'Roman Holiday'),
#  ('1953', 'Actor in a Supporting Role', None, 'Brandon De Wilde', 'Shane'),
#  ('1953', 'Actor in a Supporting Role', None, 'Jack Palance', 'Shane'),
#  ('1953', 'Actor in a Supporting Role', '1.0', 'Frank Sinatra', 'From Here to Eternity'),
#  ('1953', 'Actor in a Supporting Role', None, 'Robert Strauss', 'Stalag 17'),
#  ('1953', 'Actress in a Supporting Role', None, 'Grace Kelly', 'Mogambo'),
#  ('1953', 'Actress in a Supporting Role', None, 'Geraldine Page', 'Hondo'),
#  ('1953', 'Actress in a Supporting Role', None, 'Marjorie Rambeau', 'Torch Song'),
#  ('1953', 'Actress in a Supporting Role', '1.0', 'Donna Reed', 'From Here to Eternity'),
#  ('1953', 'Actress in a Supporting Role', None, 'Thelma Ritter', 'Pickup on South Street'),
#  ('1954', 'Actor in a Supporting Role', None, 'Lee J. Cobb', 'On the Waterfront'),
#  ('1954', 'Actor in a Supporting Role', None, 'Karl Malden', 'On the Waterfront'),
#  ('1954', 'Actor in a Supporting Role', '1.0', "Edmond O'Brien", 'The Barefoot Contessa'),
#  ('1954', 'Actor in a Supporting Role', None, 'Rod Steiger', 'On the Waterfront'),
#  ('1954', 'Actor in a Supporting Role', None, 'Tom Tully', 'The Caine Mutiny'),
#  ('1954', 'Actress in a Supporting Role', None, 'Nina Foch', 'Executive Suite'),
#  ('1954', 'Actress in a Supporting Role', None, 'Katy Jurado', 'Broken Lance'),
#  ('1954', 'Actress in a Supporting Role', '1.0', 'Eva Marie Saint', 'On the Waterfront'),
#  ('1954', 'Actress in a Supporting Role', None, 'Jan Sterling', 'The High and the Mighty'),
#  ('1954', 'Actress in a Supporting Role', None, 'Claire Trevor', 'The High and the Mighty'),
#  ('1955', 'Actor in a Supporting Role', None, 'Arthur Kennedy', 'Trial'),
#  ('1955', 'Actor in a Supporting Role', '1.0', 'Jack Lemmon', 'Mister Roberts'),
#  ('1955', 'Actor in a Supporting Role', None, 'Joe Mantell', 'Marty'),
#  ('1955', 'Actor in a Supporting Role', None, 'Sal Mineo', 'Rebel without a Cause'),
#  ('1955', 'Actor in a Supporting Role', None, "Arthur O'Connell", 'Picnic'),
#  ('1955', 'Actress in a Supporting Role', None, 'Betsy Blair', 'Marty'),
#  ('1955', 'Actress in a Supporting Role', None, 'Peggy Lee', "Pete Kelly's Blues"),
#  ('1955', 'Actress in a Supporting Role', None, 'Marisa Pavan', 'The Rose Tattoo'),
#  ('1955', 'Actress in a Supporting Role', '1.0', 'Jo Van Fleet', 'East of Eden'),
#  ('1955', 'Actress in a Supporting Role', None, 'Natalie Wood', 'Rebel without a Cause'),
#  ('1956', 'Actor in a Supporting Role', None, 'Don Murray', 'Bus Stop'),
#  ('1956', 'Actor in a Supporting Role', None, 'Anthony Perkins', 'Friendly Persuasion'),
#  ('1956', 'Actor in a Supporting Role', '1.0', 'Anthony Quinn', 'Lust for Life'),
#  ('1956', 'Actor in a Supporting Role', None, 'Mickey Rooney', 'The Bold and the Brave'),
#  ('1956', 'Actor in a Supporting Role', None, 'Robert Stack', 'Written on the Wind'),
#  ('1956', 'Actress in a Supporting Role', None, 'Mildred Dunnock', 'Baby Doll'),
#  ('1956', 'Actress in a Supporting Role', None, 'Eileen Heckart', 'The Bad Seed'),
#  ('1956', 'Actress in a Supporting Role', None, 'Mercedes McCambridge', 'Giant'),
#  ('1956', 'Actress in a Supporting Role', None, 'Patty McCormack', 'The Bad Seed'),
#  ('1956', 'Actress in a Supporting Role', '1.0', 'Dorothy Malone', 'Written on the Wind'),
#  ('1957', 'Actor in a Supporting Role', '1.0', 'Red Buttons', 'Sayonara'),
#  ('1957', 'Actor in a Supporting Role', None, 'Vittorio De Sica', 'A Farewell to Arms'),
#  ('1957', 'Actor in a Supporting Role', None, 'Sessue Hayakawa', 'The Bridge on the River Kwai'),
#  ('1957', 'Actor in a Supporting Role', None, 'Arthur Kennedy', 'Peyton Place'),
#  ('1957', 'Actor in a Supporting Role', None, 'Russ Tamblyn', 'Peyton Place'),
#  ('1957', 'Actress in a Supporting Role', None, 'Carolyn Jones', 'The Bachelor Party'),
#  ('1957', 'Actress in a Supporting Role', None, 'Elsa Lanchester', 'Witness for the Prosecution'),
#  ('1957', 'Actress in a Supporting Role', None, 'Hope Lange', 'Peyton Place'),
#  ('1957', 'Actress in a Supporting Role', '1.0', 'Miyoshi Umeki', 'Sayonara'),
#  ('1957', 'Actress in a Supporting Role', None, 'Diane Varsi', 'Peyton Place'),
#  ('1958', 'Actor in a Supporting Role', None, 'Theodore Bikel', 'The Defiant Ones'),
#  ('1958', 'Actor in a Supporting Role', None, 'Lee J. Cobb', 'The Brothers Karamazov'),
#  ('1958', 'Actor in a Supporting Role', '1.0', 'Burl Ives', 'The Big Country'),
#  ('1958', 'Actor in a Supporting Role', None, 'Arthur Kennedy', 'Some Came Running'),
#  ('1958', 'Actor in a Supporting Role', None, 'Gig Young', "Teacher's Pet"),
#  ('1958', 'Actress in a Supporting Role', None, 'Peggy Cass', 'Auntie Mame'),
#  ('1958', 'Actress in a Supporting Role', '1.0', 'Wendy Hiller', 'Separate Tables'),
#  ('1958', 'Actress in a Supporting Role', None, 'Martha Hyer', 'Some Came Running'),
#  ('1958', 'Actress in a Supporting Role', None, 'Maureen Stapleton', 'Lonelyhearts'),
#  ('1958', 'Actress in a Supporting Role', None, 'Cara Williams', 'The Defiant Ones'),
#  ('1959', 'Actor in a Supporting Role', '1.0', 'Hugh Griffith', 'Ben-Hur'),
#  ('1959', 'Actor in a Supporting Role', None, "Arthur O'Connell", 'Anatomy of a Murder'),
#  ('1959', 'Actor in a Supporting Role', None, 'George C. Scott', 'Anatomy of a Murder'),
#  ('1959', 'Actor in a Supporting Role', None, 'Robert Vaughn', 'The Young Philadelphians'),
#  ('1959', 'Actor in a Supporting Role', None, 'Ed Wynn', 'The Diary of Anne Frank'),
#  ('1959', 'Actress in a Supporting Role', None, 'Hermione Baddeley', 'Room at the Top'),
#  ('1959', 'Actress in a Supporting Role', None, 'Susan Kohner', 'Imitation of Life'),
#  ('1959', 'Actress in a Supporting Role', None, 'Juanita Moore', 'Imitation of Life'),
#  ('1959', 'Actress in a Supporting Role', None, 'Thelma Ritter', 'Pillow Talk'),
#  ('1959', 'Actress in a Supporting Role', '1.0', 'Shelley Winters', 'The Diary of Anne Frank'),
#  ('1960', 'Actor in a Supporting Role', None, 'Peter Falk', 'Murder, Inc.'),
#  ('1960', 'Actor in a Supporting Role', None, 'Jack Kruschen', 'The Apartment'),
#  ('1960', 'Actor in a Supporting Role', None, 'Sal Mineo', 'Exodus'),
#  ('1960', 'Actor in a Supporting Role', '1.0', 'Peter Ustinov', 'Spartacus'),
#  ('1960', 'Actor in a Supporting Role', None, 'Chill Wills', 'The Alamo'),
#  ('1960', 'Actress in a Supporting Role', None, 'Glynis Johns', 'The Sundowners'),
#  ('1960', 'Actress in a Supporting Role', '1.0', 'Shirley Jones', 'Elmer Gantry'),
#  ('1960', 'Actress in a Supporting Role', None, 'Shirley Knight', 'The Dark at the Top of the Stairs'),
#  ('1960', 'Actress in a Supporting Role', None, 'Janet Leigh', 'Psycho'),
#  ('1960', 'Actress in a Supporting Role', None, 'Mary Ure', 'Sons and Lovers'),
#  ('1961', 'Actor in a Supporting Role', '1.0', 'George Chakiris', 'West Side Story'),
#  ('1961', 'Actor in a Supporting Role', None, 'Montgomery Clift', 'Judgment at Nuremberg'),
#  ('1961', 'Actor in a Supporting Role', None, 'Peter Falk', 'Pocketful of Miracles'),
#  ('1961', 'Actor in a Supporting Role', None, 'Jackie Gleason', 'The Hustler'),
#  ('1961', 'Actor in a Supporting Role', None, 'George C. Scott', 'The Hustler'),
#  ('1961', 'Actress in a Supporting Role', None, 'Fay Bainter', "The Children's Hour"),
#  ('1961', 'Actress in a Supporting Role', None, 'Judy Garland', 'Judgment at Nuremberg'),
#  ('1961', 'Actress in a Supporting Role', None, 'Lotte Lenya', 'The Roman Spring of Mrs. Stone'),
#  ('1961', 'Actress in a Supporting Role', None, 'Una Merkel', 'Summer and Smoke'),
#  ('1961', 'Actress in a Supporting Role', '1.0', 'Rita Moreno', 'West Side Story'),
#  ('1962', 'Actor in a Supporting Role', '1.0', 'Ed Begley', 'Sweet Bird of Youth'),
#  ('1962', 'Actor in a Supporting Role', None, 'Victor Buono', 'What Ever Happened to Baby Jane?'),
#  ('1962', 'Actor in a Supporting Role', None, 'Telly Savalas', 'Birdman of Alcatraz'),
#  ('1962', 'Actor in a Supporting Role', None, 'Omar Sharif', 'Lawrence of Arabia'),
#  ('1962', 'Actor in a Supporting Role', None, 'Terence Stamp', 'Billy Budd'),
#  ('1962', 'Actress in a Supporting Role', None, 'Mary Badham', 'To Kill a Mockingbird'),
#  ('1962', 'Actress in a Supporting Role', '1.0', 'Patty Duke', 'The Miracle Worker'),
#  ('1962', 'Actress in a Supporting Role', None, 'Shirley Knight', 'Sweet Bird of Youth'),
#  ('1962', 'Actress in a Supporting Role', None, 'Angela Lansbury', 'The Manchurian Candidate'),
#  ('1962', 'Actress in a Supporting Role', None, 'Thelma Ritter', 'Birdman of Alcatraz'),
#  ('1962', 'Best Picture', '1.0', 'Lawrence of Arabia ', 'Sam Spiegel, Producer'),
#  ('1962', 'Best Picture', None, 'The Longest Day ', 'Darryl F. Zanuck, Producer'),
#  ('1962', 'Best Picture', None, "Meredith Willson's The Music Man ", 'Morton Da Costa, Producer'),
#  ('1962', 'Best Picture', None, 'Mutiny on the Bounty ', 'Aaron Rosenberg, Producer'),
#  ('1962', 'Best Picture', None, 'To Kill a Mockingbird ', 'Alan J. Pakula, Producer'),
#  ('1963', 'Actor in a Supporting Role', None, 'Nick Adams', 'Twilight of Honor'),
#  ('1963', 'Actor in a Supporting Role', None, 'Bobby Darin', 'Captain Newman, M.D.'),
#  ('1963', 'Actor in a Supporting Role', '1.0', 'Melvyn Douglas', 'Hud'),
#  ('1963', 'Actor in a Supporting Role', None, 'Hugh Griffith', 'Tom Jones'),
#  ('1963', 'Actor in a Supporting Role', None, 'John Huston', 'The Cardinal'),
#  ('1963', 'Actress in a Supporting Role', None, 'Diane Cilento', 'Tom Jones'),
#  ('1963', 'Actress in a Supporting Role', None, 'Dame Edith Evans', 'Tom Jones'),
#  ('1963', 'Actress in a Supporting Role', None, 'Joyce Redman', 'Tom Jones'),
#  ('1963', 'Actress in a Supporting Role', '1.0', 'Margaret Rutherford', 'The V.I.P.s'),
#  ('1963', 'Actress in a Supporting Role', None, 'Lilia Skala', 'Lilies of the Field'),
#  ('1963', 'Best Picture', None, 'America America ', 'Elia Kazan, Producer'),
#  ('1963', 'Best Picture', None, 'Cleopatra ', 'Walter Wanger, Producer'),
#  ('1963', 'Best Picture', None, 'How the West Was Won ', 'Bernard Smith, Producer'),
#  ('1963', 'Best Picture', None, 'Lilies of the Field ', 'Ralph Nelson, Producer'),
#  ('1963', 'Best Picture', '1.0', 'Tom Jones ', 'Tony Richardson, Producer'),
#  ('1964', 'Actor in a Supporting Role', None, 'John Gielgud', 'Becket'),
#  ('1964', 'Actor in a Supporting Role', None, 'Stanley Holloway', 'My Fair Lady'),
#  ('1964', 'Actor in a Supporting Role', None, "Edmond O'Brien", 'Seven Days in May'),
#  ('1964', 'Actor in a Supporting Role', None, 'Lee Tracy', 'The Best Man'),
#  ('1964', 'Actor in a Supporting Role', '1.0', 'Peter Ustinov', 'Topkapi'),
#  ('1964', 'Actress in a Supporting Role', None, 'Gladys Cooper', 'My Fair Lady'),
#  ('1964', 'Actress in a Supporting Role', None, 'Dame Edith Evans', 'The Chalk Garden'),
#  ('1964', 'Actress in a Supporting Role', None, 'Grayson Hall', 'The Night of the Iguana'),
#  ('1964', 'Actress in a Supporting Role', '1.0', 'Lila Kedrova', 'Zorba the Greek'),
#  ('1964', 'Actress in a Supporting Role', None, 'Agnes Moorehead', 'Hush...Hush, Sweet Charlotte'),
#  ('1964', 'Best Picture', None, 'Becket ', 'Hal B. Wallis, Producer'),
#  ('1964', 'Best Picture', None, 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb ', 'Stanley Kubrick, Producer'),
#  ('1964', 'Best Picture', None, 'Mary Poppins ', 'Walt Disney and Bill Walsh, Producers'),
#  ('1964', 'Best Picture', '1.0', 'My Fair Lady ', 'Jack L. Warner, Producer'),
#  ('1964', 'Best Picture', None, 'Zorba the Greek ', 'Michael Cacoyannis, Producer'),
#  ('1965', 'Actor in a Supporting Role', '1.0', 'Martin Balsam', 'A Thousand Clowns'),
#  ('1965', 'Actor in a Supporting Role', None, 'Ian Bannen', 'The Flight of the Phoenix'),
#  ('1965', 'Actor in a Supporting Role', None, 'Tom Courtenay', 'Doctor Zhivago'),
#  ('1965', 'Actor in a Supporting Role', None, 'Michael Dunn', 'Ship of Fools'),
#  ('1965', 'Actor in a Supporting Role', None, 'Frank Finlay', 'Othello'),
#  ('1965', 'Actress in a Supporting Role', None, 'Ruth Gordon', 'Inside Daisy Clover'),
#  ('1965', 'Actress in a Supporting Role', None, 'Joyce Redman', 'Othello'),
#  ('1965', 'Actress in a Supporting Role', None, 'Maggie Smith', 'Othello'),
#  ('1965', 'Actress in a Supporting Role', '1.0', 'Shelley Winters', 'A Patch of Blue'),
#  ('1965', 'Actress in a Supporting Role', None, 'Peggy Wood', 'The Sound of Music'),
#  ('1965', 'Best Picture', None, 'Darling ', 'Joseph Janni, Producer'),
#  ('1965', 'Best Picture', None, 'Doctor Zhivago ', 'Carlo Ponti, Producer'),
#  ('1965', 'Best Picture', None, 'Ship of Fools ', 'Stanley Kramer, Producer'),
#  ('1965', 'Best Picture', '1.0', 'The Sound of Music ', 'Robert Wise, Producer'),
#  ('1965', 'Best Picture', None, 'A Thousand Clowns ', 'Fred Coe, Producer'),
#  ('1966', 'Actor in a Supporting Role', None, 'Mako', 'The Sand Pebbles'),
#  ('1966', 'Actor in a Supporting Role', None, 'James Mason', 'Georgy Girl'),
#  ('1966', 'Actor in a Supporting Role', '1.0', 'Walter Matthau', 'The Fortune Cookie'),
#  ('1966', 'Actor in a Supporting Role', None, 'George Segal', "Who's Afraid of Virginia Woolf?"),
#  ('1966', 'Actor in a Supporting Role', None, 'Robert Shaw', 'A Man for All Seasons'),
#  ('1966', 'Actress in a Supporting Role', '1.0', 'Sandy Dennis', "Who's Afraid of Virginia Woolf?"),
#  ('1966', 'Actress in a Supporting Role', None, 'Wendy Hiller', 'A Man for All Seasons'),
#  ('1966', 'Actress in a Supporting Role', None, 'Jocelyne Lagarde', 'Hawaii'),
#  ('1966', 'Actress in a Supporting Role', None, 'Vivien Merchant', 'Alfie'),
#  ('1966', 'Actress in a Supporting Role', None, 'Geraldine Page', "You're a Big Boy Now"),
#  ('1966', 'Best Picture', None, 'Alfie ', 'Lewis Gilbert, Producer'),
#  ('1966', 'Best Picture', '1.0', 'A Man for All Seasons ', 'Fred Zinnemann, Producer'),
#  ('1966', 'Best Picture', None, 'The Russians Are Coming The Russians Are Coming ', 'Norman Jewison, Producer'),
#  ('1966', 'Best Picture', None, 'The Sand Pebbles ', 'Robert Wise, Producer'),
#  ('1966', 'Best Picture', None, "Who's Afraid of Virginia Woolf? ", 'Ernest Lehman, Producer'),
#  ('1967', 'Actor in a Supporting Role', None, 'John Cassavetes', 'The Dirty Dozen'),
#  ('1967', 'Actor in a Supporting Role', None, 'Gene Hackman', 'Bonnie and Clyde'),
#  ('1967', 'Actor in a Supporting Role', None, 'Cecil Kellaway', "Guess Who's Coming to Dinner"),
#  ('1967', 'Actor in a Supporting Role', '1.0', 'George Kennedy', 'Cool Hand Luke'),
#  ('1967', 'Actor in a Supporting Role', None, 'Michael J. Pollard', 'Bonnie and Clyde'),
#  ('1967', 'Actress in a Supporting Role', None, 'Carol Channing', 'Thoroughly Modern Millie'),
#  ('1967', 'Actress in a Supporting Role', None, 'Mildred Natwick', 'Barefoot in the Park'),
#  ('1967', 'Actress in a Supporting Role', '1.0', 'Estelle Parsons', 'Bonnie and Clyde'),
#  ('1967', 'Actress in a Supporting Role', None, 'Beah Richards', "Guess Who's Coming to Dinner"),
#  ('1967', 'Actress in a Supporting Role', None, 'Katharine Ross', 'The Graduate'),
#  ('1967', 'Best Picture', None, 'Bonnie and Clyde ', 'Warren Beatty, Producer'),
#  ('1967', 'Best Picture', None, 'Doctor Dolittle ', 'Arthur P. Jacobs, Producer'),
#  ('1967', 'Best Picture', None, 'The Graduate ', 'Lawrence Turman, Producer'),
#  ('1967', 'Best Picture', None, "Guess Who's Coming to Dinner ", 'Stanley Kramer, Producer'),
#  ('1967', 'Best Picture', '1.0', 'In the Heat of the Night ', 'Walter Mirisch, Producer'),
#  ('1968', 'Actor in a Supporting Role', '1.0', 'Jack Albertson', 'The Subject Was Roses'),
#  ('1968', 'Actor in a Supporting Role', None, 'Seymour Cassel', 'Faces'),
#  ('1968', 'Actor in a Supporting Role', None, 'Daniel Massey', 'Star!'),
#  ('1968', 'Actor in a Supporting Role', None, 'Jack Wild', 'Oliver!'),
#  ('1968', 'Actor in a Supporting Role', None, 'Gene Wilder', 'The Producers'),
#  ('1968', 'Actress in a Supporting Role', None, 'Lynn Carlin', 'Faces'),
#  ('1968', 'Actress in a Supporting Role', '1.0', 'Ruth Gordon', "Rosemary's Baby"),
#  ('1968', 'Actress in a Supporting Role', None, 'Sondra Locke', 'The Heart Is a Lonely Hunter'),
#  ('1968', 'Actress in a Supporting Role', None, 'Kay Medford', 'Funny Girl'),
#  ('1968', 'Actress in a Supporting Role', None, 'Estelle Parsons', 'Rachel, Rachel'),
#  ('1968', 'Best Picture', None, 'Funny Girl ', 'Ray Stark, Producer'),
#  ('1968', 'Best Picture', None, 'The Lion in Winter ', 'Martin Poll, Producer'),
#  ('1968', 'Best Picture', '1.0', 'Oliver! ', 'John Woolf, Producer'),
#  ('1968', 'Best Picture', None, 'Rachel, Rachel ', 'Paul Newman, Producer'),
#  ('1968', 'Best Picture', None, 'Romeo and Juliet ', 'Anthony Havelock-Allan and John Brabourne, Producers'),
#  ('1969', 'Actor in a Supporting Role', None, 'Rupert Crosse', 'The Reivers'),
#  ('1969', 'Actor in a Supporting Role', None, 'Elliott Gould', 'Bob & Carol & Ted & Alice'),
#  ('1969', 'Actor in a Supporting Role', None, 'Jack Nicholson', 'Easy Rider'),
#  ('1969', 'Actor in a Supporting Role', None, 'Anthony Quayle', 'Anne of the Thousand Days'),
#  ('1969', 'Actor in a Supporting Role', '1.0', 'Gig Young', "They Shoot Horses, Don't They?"),
#  ('1969', 'Actress in a Supporting Role', None, 'Catherine Burns', 'Last Summer'),
#  ('1969', 'Actress in a Supporting Role', None, 'Dyan Cannon', 'Bob & Carol & Ted & Alice'),
#  ('1969', 'Actress in a Supporting Role', '1.0', 'Goldie Hawn', 'Cactus Flower'),
#  ('1969', 'Actress in a Supporting Role', None, 'Sylvia Miles', 'Midnight Cowboy'),
#  ('1969', 'Actress in a Supporting Role', None, 'Susannah York', "They Shoot Horses, Don't They?"),
#  ('1969', 'Best Picture', None, 'Anne of the Thousand Days ', 'Hal B. Wallis, Producer'),
#  ('1969', 'Best Picture', None, 'Butch Cassidy and the Sundance Kid ', 'John Foreman, Producer'),
#  ('1969', 'Best Picture', None, 'Hello, Dolly! ', 'Ernest Lehman, Producer'),
#  ('1969', 'Best Picture', '1.0', 'Midnight Cowboy ', 'Jerome Hellman, Producer'),
#  ('1969', 'Best Picture', None, 'Z ', 'Jacques Perrin and Hamed Rachedi, Producers'),
#  ('1970', 'Actor in a Supporting Role', None, 'Richard Castellano', 'Lovers and Other Strangers'),
#  ('1970', 'Actor in a Supporting Role', None, 'Chief Dan George', 'Little Big Man'),
#  ('1970', 'Actor in a Supporting Role', None, 'Gene Hackman', 'I Never Sang for My Father'),
#  ('1970', 'Actor in a Supporting Role', None, 'John Marley', 'Love Story'),
#  ('1970', 'Actor in a Supporting Role', '1.0', 'John Mills', "Ryan's Daughter"),
#  ('1970', 'Actress in a Supporting Role', None, 'Karen Black', 'Five Easy Pieces'),
#  ('1970', 'Actress in a Supporting Role', None, 'Lee Grant', 'The Landlord'),
#  ('1970', 'Actress in a Supporting Role', '1.0', 'Helen Hayes', 'Airport'),
#  ('1970', 'Actress in a Supporting Role', '1.0', 'Sally Kellerman', 'MA*S*H'),
#  ('1970', 'Actress in a Supporting Role', None, 'Maureen Stapleton', 'Airport'),
#  ('1970', 'Best Picture', None, 'Airport ', 'Ross Hunter, Producer'),
#  ('1970', 'Best Picture', None, 'Five Easy Pieces ', 'Bob Rafelson and Richard Wechsler, Producers'),
#  ('1970', 'Best Picture', None, 'Love Story ', 'Howard G. Minsky, Producer'),
#  ('1970', 'Best Picture', '1.0', 'MA*S*H ', 'Ingo Preminger, Producer'),
#  ('1970', 'Best Picture', '1.0', 'Patton ', 'Frank McCarthy, Producer'),
#  ('1971', 'Actor in a Supporting Role', None, 'Jeff Bridges', 'The Last Picture Show'),
#  ('1971', 'Actor in a Supporting Role', None, 'Leonard Frey', 'Fiddler on the Roof'),
#  ('1971', 'Actor in a Supporting Role', None, 'Richard Jaeckel', 'Sometimes a Great Notion'),
#  ('1971', 'Actor in a Supporting Role', '1.0', 'Ben Johnson', 'The Last Picture Show'),
#  ('1971', 'Actor in a Supporting Role', None, 'Roy Scheider', 'The French Connection'),
#  ('1971', 'Actress in a Supporting Role', None, 'Ann-Margret', 'Carnal Knowledge'),
#  ('1971', 'Actress in a Supporting Role', None, 'Ellen Burstyn', 'The Last Picture Show'),
#  ('1971', 'Actress in a Supporting Role', None, 'Barbara Harris', 'Who Is Harry Kellerman and Why Is He Saying Those Terrible Things about Me?'),
#  ('1971', 'Actress in a Supporting Role', '1.0', 'Cloris Leachman', 'The Last Picture Show'),
#  ('1971', 'Actress in a Supporting Role', None, 'Margaret Leighton', 'The Go-Between'),
#  ('1971', 'Best Picture', None, 'A Clockwork Orange ', 'Stanley Kubrick, Producer'),
#  ('1971', 'Best Picture', None, 'Fiddler on the Roof ', 'Norman Jewison, Producer'),
#  ('1971', 'Best Picture', '1.0', 'The French Connection ', "Philip D'Antoni, Producer"),
#  ('1971', 'Best Picture', None, 'The Last Picture Show ', 'Stephen J. Friedman, Producer'),
#  ('1971', 'Best Picture', None, 'Nicholas and Alexandra ', 'Sam Spiegel, Producer'),
#  ('1972', 'Actor in a Supporting Role', None, 'Eddie Albert', 'The Heartbreak Kid'),
#  ('1972', 'Actor in a Supporting Role', None, 'James Caan', 'The Godfather'),
#  ('1972', 'Actor in a Supporting Role', None, 'Robert Duvall', 'The Godfather'),
#  ('1972', 'Actor in a Supporting Role', '1.0', 'Joel Grey', 'Cabaret'),
#  ('1972', 'Actor in a Supporting Role', None, 'Al Pacino', 'The Godfather'),
#  ('1972', 'Actress in a Supporting Role', None, 'Jeannie Berlin', 'The Heartbreak Kid'),
#  ('1972', 'Actress in a Supporting Role', '1.0', 'Eileen Heckart', 'Butterflies Are Free'),
#  ('1972', 'Actress in a Supporting Role', None, 'Geraldine Page', "Pete 'n' Tillie"),
#  ('1972', 'Actress in a Supporting Role', None, 'Susan Tyrrell', 'Fat City'),
#  ('1972', 'Actress in a Supporting Role', None, 'Shelley Winters', 'The Poseidon Adventure'),
#  ('1972', 'Best Picture', None, 'Cabaret ', 'Cy Feuer, Producer'),
#  ('1972', 'Best Picture', None, 'Deliverance ', 'John Boorman, Producer'),
#  ('1972', 'Best Picture', None, 'The Emigrants ', 'Bengt Forslund, Producer'),
#  ('1972', 'Best Picture', '1.0', 'The Godfather ', 'Albert S. Ruddy, Producer'),
#  ('1972', 'Best Picture', None, 'Sounder ', 'Robert B. Radnitz, Producer'),
#  ('1973', 'Actor in a Supporting Role', None, 'Vincent Gardenia', 'Bang the Drum Slowly'),
#  ('1973', 'Actor in a Supporting Role', None, 'Jack Gilford', 'Save the Tiger'),
#  ('1973', 'Actor in a Supporting Role', '1.0', 'John Houseman', 'The Paper Chase'),
#  ('1973', 'Actor in a Supporting Role', None, 'Jason Miller', 'The Exorcist'),
#  ('1973', 'Actor in a Supporting Role', None, 'Randy Quaid', 'The Last Detail'),
#  ('1973', 'Actress in a Supporting Role', None, 'Linda Blair', 'The Exorcist'),
#  ('1973', 'Actress in a Supporting Role', None, 'Candy Clark', 'American Graffiti'),
#  ('1973', 'Actress in a Supporting Role', None, 'Madeline Kahn', 'Paper Moon'),
#  ('1973', 'Actress in a Supporting Role', '1.0', "Tatum O'Neal", 'Paper Moon'),
#  ('1973', 'Actress in a Supporting Role', None, 'Sylvia Sidney', 'Summer Wishes, Winter Dreams'),
#  ('1973', 'Best Picture', None, 'American Graffiti ', 'Francis Ford Coppola, Producer; Gary Kurtz, Co-Producer'),
#  ('1973', 'Best Picture', None, 'Cries and Whispers ', 'Ingmar Bergman, Producer'),
#  ('1973', 'Best Picture', None, 'The Exorcist ', 'William Peter Blatty, Producer'),
#  ('1973', 'Best Picture', '1.0', 'The Sting ', 'Tony Bill, Michael Phillips and Julia Phillips, Producers'),
#  ('1973', 'Best Picture', None, 'A Touch of Class ', 'Melvin Frank, Producer'),
#  ('1974', 'Actor in a Supporting Role', None, 'Fred Astaire', 'The Towering Inferno'),
#  ('1974', 'Actor in a Supporting Role', None, 'Jeff Bridges', 'Thunderbolt and Lightfoot'),
#  ('1974', 'Actor in a Supporting Role', '1.0', 'Robert De Niro', 'The Godfather Part II'),
#  ('1974', 'Actor in a Supporting Role', None, 'Michael V. Gazzo', 'The Godfather Part II'),
#  ('1974', 'Actor in a Supporting Role', None, 'Lee Strasberg', 'The Godfather Part II'),
#  ('1974', 'Actress in a Supporting Role', '1.0', 'Ingrid Bergman', 'Murder on the Orient Express'),
#  ('1974', 'Actress in a Supporting Role', None, 'Valentina Cortese', 'Day for Night'),
#  ('1974', 'Actress in a Supporting Role', None, 'Madeline Kahn', 'Blazing Saddles'),
#  ('1974', 'Actress in a Supporting Role', None, 'Diane Ladd', "Alice Doesn't Live Here Anymore"),
#  ('1974', 'Actress in a Supporting Role', None, 'Talia Shire', 'The Godfather Part II'),
#  ('1974', 'Best Picture', None, 'Chinatown ', 'Robert Evans, Producer'),
#  ('1974', 'Best Picture', None, 'The Conversation ', 'Francis Ford Coppola, Producer; Fred Roos, Co-Producer'),
#  ('1974', 'Best Picture', '1.0', 'The Godfather Part II ', 'Francis Ford Coppola, Producer; Gray Frederickson and Fred Roos, Co-Producers'),
#  ('1974', 'Best Picture', None, 'Lenny ', 'Marvin Worth, Producer'),
#  ('1974', 'Best Picture', None, 'The Towering Inferno ', 'Irwin Allen, Producer'),
#  ('1975', 'Actor in a Supporting Role', '1.0', 'George Burns', 'The Sunshine Boys'),
#  ('1975', 'Actor in a Supporting Role', None, 'Brad Dourif', "One Flew over the Cuckoo's Nest"),
#  ('1975', 'Actor in a Supporting Role', None, 'Burgess Meredith', 'The Day of the Locust'),
#  ('1975', 'Actor in a Supporting Role', None, 'Chris Sarandon', 'Dog Day Afternoon'),
#  ('1975', 'Actor in a Supporting Role', None, 'Jack Warden', 'Shampoo'),
#  ('1975', 'Actress in a Supporting Role', None, 'Ronee Blakley', 'Nashville'),
#  ('1975', 'Actress in a Supporting Role', '1.0', 'Lee Grant', 'Shampoo'),
#  ('1975', 'Actress in a Supporting Role', None, 'Sylvia Miles', 'Farewell, My Lovely'),
#  ('1975', 'Actress in a Supporting Role', None, 'Lily Tomlin', 'Nashville'),
#  ('1975', 'Actress in a Supporting Role', None, 'Brenda Vaccaro', "Jacqueline Susann's Once Is Not Enough"),
#  ('1975', 'Best Picture', None, 'Barry Lyndon ', 'Stanley Kubrick, Producer'),
#  ('1975', 'Best Picture', None, 'Dog Day Afternoon ', 'Martin Bregman and Martin Elfand, Producers'),
#  ('1975', 'Best Picture', None, 'Jaws ', 'Richard D. Zanuck and David Brown, Producers'),
#  ('1975', 'Best Picture', None, 'Nashville ', 'Robert Altman, Producer'),
#  ('1975', 'Best Picture', '1.0', "One Flew over the Cuckoo's Nest ", 'Saul Zaentz and Michael Douglas, Producers'),
#  ('1976', 'Actor in a Supporting Role', None, 'Ned Beatty', 'Network'),
#  ('1976', 'Actor in a Supporting Role', None, 'Burgess Meredith', 'Rocky'),
#  ('1976', 'Actor in a Supporting Role', None, 'Laurence Olivier', 'Marathon Man'),
#  ('1976', 'Actor in a Supporting Role', '1.0', 'Jason Robards', "All the President's Men"),
#  ('1976', 'Actor in a Supporting Role', None, 'Burt Young', 'Rocky'),
#  ('1976', 'Actress in a Supporting Role', None, 'Jane Alexander', "All the President's Men"),
#  ('1976', 'Actress in a Supporting Role', None, 'Jodie Foster', 'Taxi Driver'),
#  ('1976', 'Actress in a Supporting Role', None, 'Lee Grant', 'Voyage of the Damned'),
#  ('1976', 'Actress in a Supporting Role', None, 'Piper Laurie', 'Carrie'),
#  ('1976', 'Actress in a Supporting Role', '1.0', 'Beatrice Straight', 'Network'),
#  ('1976', 'Best Picture', None, "All the President's Men ", 'Walter Coblenz, Producer'),
#  ('1976', 'Best Picture', None, 'Bound for Glory ', 'Robert F. Blumofe and Harold Leventhal, Producers'),
#  ('1976', 'Best Picture', None, 'Network ', 'Howard Gottfried, Producer'),
#  ('1976', 'Best Picture', '1.0', 'Rocky ', 'Irwin Winkler and Robert Chartoff, Producers'),
#  ('1976', 'Best Picture', None, 'Taxi Driver ', 'Michael Phillips and Julia Phillips, Producers'),
#  ('1977', 'Actor in a Supporting Role', None, 'Mikhail Baryshnikov', 'The Turning Point'),
#  ('1977', 'Actor in a Supporting Role', None, 'Peter Firth', 'Equus'),
#  ('1977', 'Actor in a Supporting Role', None, 'Alec Guinness', 'Star Wars'),
#  ('1977', 'Actor in a Supporting Role', '1.0', 'Jason Robards', 'Julia'),
#  ('1977', 'Actor in a Supporting Role', None, 'Maximilian Schell', 'Julia'),
#  ('1977', 'Actress in a Supporting Role', None, 'Leslie Browne', 'The Turning Point'),
#  ('1977', 'Actress in a Supporting Role', None, 'Quinn Cummings', 'The Goodbye Girl'),
#  ('1977', 'Actress in a Supporting Role', None, 'Melinda Dillon', 'Close Encounters of the Third Kind'),
#  ('1977', 'Actress in a Supporting Role', '1.0', 'Vanessa Redgrave', 'Julia'),
#  ('1977', 'Actress in a Supporting Role', None, 'Tuesday Weld', 'Looking for Mr. Goodbar'),
#  ('1977', 'Best Picture', '1.0', 'Annie Hall ', 'Charles H. Joffe, Producer'),
#  ('1977', 'Best Picture', None, 'The Goodbye Girl ', 'Ray Stark, Producer'),
#  ('1977', 'Best Picture', None, 'Julia ', 'Richard Roth, Producer'),
#  ('1977', 'Best Picture', None, 'Star Wars ', 'Gary Kurtz, Producer'),
#  ('1977', 'Best Picture', None, 'The Turning Point ', 'Herbert Ross and Arthur Laurents, Producers'),
#  ('1977', 'Special Achievement Award', '1.0', 'Benjamin Burtt, Jr.', 'Star Wars'),
#  ('1978', 'Actor in a Supporting Role', None, 'Bruce Dern', 'Coming Home'),
#  ('1978', 'Actor in a Supporting Role', None, 'Richard Farnsworth', 'Comes a Horseman'),
#  ('1978', 'Actor in a Supporting Role', None, 'John Hurt', 'Midnight Express'),
#  ('1978', 'Actor in a Supporting Role', '1.0', 'Christopher Walken', 'The Deer Hunter'),
#  ('1978', 'Actor in a Supporting Role', None, 'Jack Warden', 'Heaven Can Wait'),
#  ('1978', 'Actress in a Supporting Role', None, 'Dyan Cannon', 'Heaven Can Wait'),
#  ('1978', 'Actress in a Supporting Role', None, 'Penelope Milford', 'Coming Home'),
#  ('1978', 'Actress in a Supporting Role', '1.0', 'Maggie Smith', 'California Suite'),
#  ('1978', 'Actress in a Supporting Role', None, 'Maureen Stapleton', 'Interiors'),
#  ('1978', 'Actress in a Supporting Role', None, 'Meryl Streep', 'The Deer Hunter'),
#  ('1978', 'Best Picture', None, 'Coming Home ', 'Jerome Hellman, Producer'),
#  ('1978', 'Best Picture', '1.0', 'The Deer Hunter ', 'Barry Spikings, Michael Deeley, Michael Cimino and John Peverall, Producers'),
#  ('1978', 'Best Picture', None, 'Heaven Can Wait ', 'Warren Beatty, Producer'),
#  ('1978', 'Best Picture', None, 'Midnight Express ', 'Alan Marshall and David Puttnam, Producers'),
#  ('1978', 'Best Picture', None, 'An Unmarried Woman ', 'Paul Mazursky and Tony Ray, Producers'),
#  ('1979', 'Actor in a Supporting Role', '1.0', 'Melvyn Douglas', 'Being There'),
#  ('1979', 'Actor in a Supporting Role', None, 'Robert Duvall', 'Apocalypse Now'),
#  ('1979', 'Actor in a Supporting Role', None, 'Frederic Forrest', 'The Rose'),
#  ('1979', 'Actor in a Supporting Role', None, 'Justin Henry', 'Kramer vs. Kramer'),
#  ('1979', 'Actor in a Supporting Role', None, 'Mickey Rooney', 'The Black Stallion'),
#  ('1979', 'Actress in a Supporting Role', None, 'Jane Alexander', 'Kramer vs. Kramer'),
#  ('1979', 'Actress in a Supporting Role', None, 'Barbara Barrie', 'Breaking Away'),
#  ('1979', 'Actress in a Supporting Role', None, 'Candice Bergen', 'Starting Over'),
#  ('1979', 'Actress in a Supporting Role', None, 'Mariel Hemingway', 'Manhattan'),
#  ('1979', 'Actress in a Supporting Role', '1.0', 'Meryl Streep', 'Kramer vs. Kramer'),
#  ('1979', 'Best Picture', None, 'All That Jazz ', 'Robert Alan Aurthur, Producer'),
#  ('1979', 'Best Picture', None, 'Apocalypse Now ', 'Francis Coppola, Producer; Fred Roos, Gray Frederickson and Tom Sternberg, Co-Producers'),
#  ('1979', 'Best Picture', None, 'Breaking Away ', 'Peter Yates, Producer'),
#  ('1979', 'Best Picture', '1.0', 'Kramer vs. Kramer ', 'Stanley R. Jaffe, Producer'),
#  ('1979', 'Best Picture', None, 'Norma Rae ', 'Tamara Asseyev and Alex Rose, Producers'),
#  ('1980', 'Actor in a Supporting Role', None, 'Judd Hirsch', 'Ordinary People'),
#  ('1980', 'Actor in a Supporting Role', '1.0', 'Timothy Hutton', 'Ordinary People'),
#  ('1980', 'Actor in a Supporting Role', None, "Michael O'Keefe", 'The Great Santini'),
#  ('1980', 'Actor in a Supporting Role', None, 'Joe Pesci', 'Raging Bull'),
#  ('1980', 'Actor in a Supporting Role', None, 'Jason Robards', 'Melvin and Howard'),
#  ('1980', 'Actress in a Supporting Role', None, 'Eileen Brennan', 'Private Benjamin'),
#  ('1980', 'Actress in a Supporting Role', None, 'Eva Le Gallienne', 'Resurrection'),
#  ('1980', 'Actress in a Supporting Role', None, 'Cathy Moriarty', 'Raging Bull'),
#  ('1980', 'Actress in a Supporting Role', None, 'Diana Scarwid', 'Inside Moves'),
#  ('1980', 'Actress in a Supporting Role', '1.0', 'Mary Steenburgen', 'Melvin and Howard'),
#  ('1980', 'Best Picture', None, "Coal Miner's Daughter ", 'Bernard Schwartz, Producer'),
#  ('1980', 'Best Picture', None, 'The Elephant Man ', 'Jonathan Sanger, Producer'),
#  ('1980', 'Best Picture', '1.0', 'Ordinary People ', 'Ronald L. Schwary, Producer'),
#  ('1980', 'Best Picture', None, 'Raging Bull ', 'Irwin Winkler and Robert Chartoff, Producers'),
#  ('1980', 'Best Picture', None, 'Tess ', 'Claude Berri, Producer; Timothy Burrill, Co-Producer'),
#  ('1981', 'Actor in a Supporting Role', None, 'James Coco', 'Only When I Laugh'),
#  ('1981', 'Actor in a Supporting Role', '1.0', 'John Gielgud', 'Arthur'),
#  ('1981', 'Actor in a Supporting Role', None, 'Ian Holm', 'Chariots of Fire'),
#  ('1981', 'Actor in a Supporting Role', None, 'Jack Nicholson', 'Reds'),
#  ('1981', 'Actor in a Supporting Role', None, 'Howard E. Rollins, Jr.', 'Ragtime'),
#  ('1981', 'Actress in a Supporting Role', None, 'Melinda Dillon', 'Absence of Malice'),
#  ('1981', 'Actress in a Supporting Role', None, 'Jane Fonda', 'On Golden Pond'),
#  ('1981', 'Actress in a Supporting Role', None, 'Joan Hackett', 'Only When I Laugh'),
#  ('1981', 'Actress in a Supporting Role', None, 'Elizabeth McGovern', 'Ragtime'),
#  ('1981', 'Actress in a Supporting Role', '1.0', 'Maureen Stapleton', 'Reds'),
#  ('1981', 'Best Picture', None, 'Atlantic City ', 'Denis Heroux and John Kemeny, Producers'),
#  ('1981', 'Best Picture', '1.0', 'Chariots of Fire ', 'David Puttnam, Producer'),
#  ('1981', 'Best Picture', None, 'On Golden Pond ', 'Bruce Gilbert, Producer'),
#  ('1981', 'Best Picture', None, 'Raiders of the Lost Ark ', 'Frank Marshall, Producer'),
#  ('1981', 'Best Picture', None, 'Reds ', 'Warren Beatty, Producer'),
#  ('1982', 'Actor in a Supporting Role', None, 'Charles Durning', 'The Best Little Whorehouse in Texas'),
# ...
#  ('1999', 'Actress in a Supporting Role', None, 'Samantha Morton', 'Sweet and Lowdown'),
#  ('1999', 'Actress in a Supporting Role', None, 'Chlo+½ Sevigny', "Boys Don't Cry"),
#  ('1999', 'Best Picture', '1.0', 'American Beauty ', 'Bruce Cohen and Dan Jinks, Producers'),
#  ('1999', 'Best Picture', None, 'The Cider House Rules ', 'Richard N. Gladstein, Producer'),
#  ('1999', 'Best Picture', None, 'The Green Mile ', 'David Valdes and Frank Darabont, Producers'),
#  ('1999', 'Best Picture', None, 'The Insider ', 'Michael Mann and Pieter Jan Brugge, Producers'),
#  ('1999', 'Best Picture', None, 'The Sixth Sense ', 'Frank Marshall, Kathleen Kennedy and Barry Mendel, Producers'),
#  ('2000', 'Actor in a Supporting Role', None, 'Jeff Bridges', 'The Contender'),
#  ('2000', 'Actor in a Supporting Role', None, 'Willem Dafoe', 'Shadow of the Vampire'),
#  ('2000', 'Actor in a Supporting Role', '1.0', 'Benicio Del Toro', 'Traffic'),
#  ('2000', 'Actor in a Supporting Role', None, 'Albert Finney', 'Erin Brockovich'),
#  ('2000', 'Actor in a Supporting Role', None, 'Joaquin Phoenix', 'Gladiator'),
#  ('2000', 'Actress in a Supporting Role', None, 'Judi Dench', 'Chocolat'),
#  ('2000', 'Actress in a Supporting Role', '1.0', 'Marcia Gay Harden', 'Pollock'),
#  ('2000', 'Actress in a Supporting Role', None, 'Kate Hudson', 'Almost Famous'),
#  ('2000', 'Actress in a Supporting Role', None, 'Frances McDormand', 'Almost Famous'),
#  ('2000', 'Actress in a Supporting Role', None, 'Julie Walters', 'Billy Elliot'),
#  ('2000', 'Best Picture', None, 'Chocolat ', 'David Brown, Kit Golden and Leslie Holleran, Producers'),
#  ('2000', 'Best Picture', None, 'Crouching Tiger, Hidden Dragon ', 'Bill Kong, Hsu Li Kong and Ang Lee, Producers'),
#  ('2000', 'Best Picture', None, 'Erin Brockovich ', 'Danny DeVito, Michael Shamberg and Stacey Sher, Producers'),
#  ('2000', 'Best Picture', '1.0', 'Gladiator ', 'Douglas Wick, David Franzoni and Branko Lustig, Producers'),
#  ('2000', 'Best Picture', None, 'Traffic ', 'Edward Zwick, Marshall Herskovitz and Laura Bickford, Producers'),
#  ('2001', 'Actor in a Supporting Role', '1.0', 'Jim Broadbent', 'Iris'),
#  ('2001', 'Actor in a Supporting Role', None, 'Ethan Hawke', 'Training Day'),
#  ('2001', 'Actor in a Supporting Role', None, 'Ben Kingsley', 'Sexy Beast'),
#  ('2001', 'Actor in a Supporting Role', None, 'Ian McKellen', 'The Lord of the Rings: The Fellowship of the Ring'),
#  ('2001', 'Actor in a Supporting Role', None, 'Jon Voight', 'Ali'),
#  ('2001', 'Actress in a Supporting Role', '1.0', 'Jennifer Connelly', 'A Beautiful Mind'),
#  ('2001', 'Actress in a Supporting Role', None, 'Helen Mirren', 'Gosford Park'),
#  ('2001', 'Actress in a Supporting Role', None, 'Maggie Smith', 'Gosford Park'),
#  ('2001', 'Actress in a Supporting Role', None, 'Marisa Tomei', 'In the Bedroom'),
#  ('2001', 'Actress in a Supporting Role', None, 'Kate Winslet', 'Iris'),
#  ('2001', 'Best Picture', '1.0', 'A Beautiful Mind ', 'Brian Grazer and Ron Howard, Producers'),
#  ('2001', 'Best Picture', None, 'Gosford Park ', 'Robert Altman, Bob Balaban and David Levy, Producers'),
#  ('2001', 'Best Picture', None, 'In the Bedroom ', 'Graham Leader, Ross Katz and Todd Field, Producers'),
#  ('2001', 'Best Picture', None, 'The Lord of the Rings: The Fellowship of the Ring ', 'Peter Jackson, Fran Walsh and Barrie M. Osborne, Producers'),
#  ('2001', 'Best Picture', None, 'Moulin Rouge ', 'Martin Brown, Baz Luhrmann and Fred Baron, Producers'),
#  ('2002', 'Actor in a Supporting Role', '1.0', 'Chris Cooper', 'Adaptation'),
#  ('2002', 'Actor in a Supporting Role', None, 'Ed Harris', 'The Hours'),
#  ('2002', 'Actor in a Supporting Role', None, 'Paul Newman', 'Road to Perdition'),
#  ('2002', 'Actor in a Supporting Role', None, 'John C. Reilly', 'Chicago'),
#  ('2002', 'Actor in a Supporting Role', None, 'Christopher Walken', 'Catch Me If You Can'),
#  ('2002', 'Actress in a Supporting Role', None, 'Kathy Bates', 'About Schmidt'),
#  ('2002', 'Actress in a Supporting Role', None, 'Julianne Moore', 'The Hours'),
#  ('2002', 'Actress in a Supporting Role', None, 'Queen Latifah', 'Chicago'),
#  ('2002', 'Actress in a Supporting Role', None, 'Meryl Streep', 'Adaptation'),
#  ('2002', 'Actress in a Supporting Role', '1.0', 'Catherine Zeta-Jones', 'Chicago'),
#  ('2002', 'Best Picture', '1.0', 'Chicago ', 'Martin Richards, Producer'),
#  ('2002', 'Best Picture', None, 'Gangs of New York ', 'Alberto Grimaldi and Harvey Weinstein, Producers'),
#  ('2002', 'Best Picture', None, 'The Hours ', 'Scott Rudin and Robert Fox, Producers'),
#  ('2002', 'Best Picture', None, 'The Lord of the Rings: The Two Towers ', 'Barrie M. Osborne, Fran Walsh and Peter Jackson, Producers'),
#  ('2002', 'Best Picture', None, 'The Pianist ', 'Roman Polanski, Robert Benmussa and Alain Sarde, Producers'),
#  ('2003', 'Actor in a Supporting Role', None, 'Alec Baldwin', 'The Cooler'),
#  ('2003', 'Actor in a Supporting Role', None, 'Benicio Del Toro', '21 Grams'),
#  ('2003', 'Actor in a Supporting Role', None, 'Djimon Hounsou', 'In America'),
#  ('2003', 'Actor in a Supporting Role', '1.0', 'Tim Robbins', 'Mystic River'),
#  ('2003', 'Actor in a Supporting Role', None, 'Ken Watanabe', 'The Last Samurai'),
#  ('2003', 'Actress in a Supporting Role', None, 'Shohreh Aghdashloo', 'House of Sand and Fog'),
#  ('2003', 'Actress in a Supporting Role', None, 'Patricia Clarkson', 'Pieces of April'),
#  ('2003', 'Actress in a Supporting Role', None, 'Marcia Gay Harden', 'Mystic River'),
#  ('2003', 'Actress in a Supporting Role', None, 'Holly Hunter', 'Thirteen'),
#  ('2003', 'Actress in a Supporting Role', '1.0', 'Ren+¬e Zellweger', 'Cold Mountain'),
#  ('2003', 'Best Picture', '1.0', 'The Lord of the Rings: The Return of the King ', 'Barrie M. Osborne, Peter Jackson and Fran Walsh, Producers'),
#  ('2003', 'Best Picture', None, 'Lost in Translation ', 'Ross Katz and Sofia Coppola, Producers'),
#  ('2003', 'Best Picture', None, 'Master and Commander: The Far Side of the World ', 'Samuel Goldwyn, Jr., Peter Weir and Duncan Henderson, Producers'),
#  ('2003', 'Best Picture', None, 'Mystic River ', 'Robert Lorenz, Judie G. Hoyt and Clint Eastwood, Producers'),
#  ('2003', 'Best Picture', None, 'Seabiscuit ', 'Kathleen Kennedy, Frank Marshall and Gary Ross, Producers'),
#  ('2004', 'Actor in a Supporting Role', None, 'Alan Alda', 'The Aviator'),
#  ('2004', 'Actor in a Supporting Role', None, 'Thomas Haden Church', 'Sideways'),
#  ('2004', 'Actor in a Supporting Role', None, 'Jamie Foxx', 'Collateral'),
#  ('2004', 'Actor in a Supporting Role', '1.0', 'Morgan Freeman', 'Million Dollar Baby'),
#  ('2004', 'Actor in a Supporting Role', None, 'Clive Owen', 'Closer'),
#  ('2004', 'Actress in a Supporting Role', '1.0', 'Cate Blanchett', 'The Aviator'),
#  ('2004', 'Actress in a Supporting Role', None, 'Laura Linney', 'Kinsey'),
#  ('2004', 'Actress in a Supporting Role', None, 'Virginia Madsen', 'Sideways'),
#  ('2004', 'Actress in a Supporting Role', None, 'Sophie Okonedo', 'Hotel Rwanda'),
#  ('2004', 'Actress in a Supporting Role', None, 'Natalie Portman', 'Closer'),
#  ('2004', 'Best Picture', None, 'The Aviator ', 'Michael Mann and Graham King, Producers'),
#  ('2004', 'Best Picture', None, 'Finding Neverland ', 'Richard N. Gladstein and Nellie Bellflower, Producers'),
#  ('2004', 'Best Picture', '1.0', 'Million Dollar Baby ', 'Clint Eastwood, Albert S. Ruddy and Tom Rosenberg, Producers'),
#  ('2004', 'Best Picture', None, 'Ray ', 'Taylor Hackford, Stuart Benjamin and Howard Baldwin, Producers'),
#  ('2004', 'Best Picture', None, 'Sideways ', 'Michael London, Producer'),
#  ('2005', 'Actor in a Supporting Role', '1.0', 'George Clooney', 'Syriana'),
#  ('2005', 'Actor in a Supporting Role', None, 'Matt Dillon', 'Crash'),
#  ('2005', 'Actor in a Supporting Role', None, 'Paul Giamatti', 'Cinderella Man'),
#  ('2005', 'Actor in a Supporting Role', None, 'Jake Gyllenhaal', 'Brokeback Mountain'),
#  ('2005', 'Actor in a Supporting Role', None, 'William Hurt', 'A History of Violence'),
#  ('2005', 'Actress in a Supporting Role', None, 'Amy Adams', 'Junebug'),
#  ('2005', 'Actress in a Supporting Role', None, 'Catherine Keener', 'Capote'),
#  ('2005', 'Actress in a Supporting Role', None, 'Frances McDormand', 'North Country'),
#  ('2005', 'Actress in a Supporting Role', '1.0', 'Rachel Weisz', 'The Constant Gardener'),
#  ('2005', 'Actress in a Supporting Role', None, 'Michelle Williams', 'Brokeback Mountain'),
#  ('2005', 'Best Picture', None, 'Brokeback Mountain ', 'Diana Ossana and James Schamus, Producers'),
#  ('2005', 'Best Picture', None, 'Capote ', 'Caroline Baron, William Vince and Michael Ohoven, Producers'),
#  ('2005', 'Best Picture', '1.0', 'Crash ', 'Paul Haggis and Cathy Schulman, Producers'),
#  ('2005', 'Best Picture', None, 'Good Night, and Good Luck. ', 'Grant Heslov, Producer'),
#  ('2005', 'Best Picture', None, 'Munich ', 'Kathleen Kennedy, Steven Spielberg and Barry Mendel, Producers'),
#  ('2006', 'Actor in a Supporting Role', '1.0', 'Alan Arkin', 'Little Miss Sunshine'),
#  ('2006', 'Actor in a Supporting Role', None, 'Jackie Earle Haley', 'Little Children'),
#  ('2006', 'Actor in a Supporting Role', None, 'Djimon Hounsou', 'Blood Diamond'),
#  ('2006', 'Actor in a Supporting Role', None, 'Eddie Murphy', 'Dreamgirls'),
#  ('2006', 'Actor in a Supporting Role', None, 'Mark Wahlberg', 'The Departed'),
#  ('2006', 'Actress in a Supporting Role', None, 'Adriana Barraza', 'Babel'),
#  ('2006', 'Actress in a Supporting Role', None, 'Cate Blanchett', 'Notes on a Scandal'),
#  ('2006', 'Actress in a Supporting Role', None, 'Abigail Breslin', 'Little Miss Sunshine'),
#  ('2006', 'Actress in a Supporting Role', '1.0', 'Jennifer Hudson', 'Dreamgirls'),
#  ('2006', 'Actress in a Supporting Role', None, 'Rinko Kikuchi', 'Babel'),
#  ('2006', 'Best Picture', None, 'Babel ', 'Alejandro Gonz+ílez I+¦+írritu, Jon Kilik and Steve Golin, Producers'),
#  ('2006', 'Best Picture', '1.0', 'The Departed ', 'Graham King, Producer'),
#  ('2006', 'Best Picture', None, 'Letters from Iwo Jima ', 'Clint Eastwood, Steven Spielberg and Robert Lorenz, Producers'),
#  ('2006', 'Best Picture', None, 'Little Miss Sunshine ', 'David T. Friendly, Peter Saraf and Marc Turtletaub, Producers'),
#  ('2006', 'Best Picture', None, 'The Queen ', 'Andy Harries, Christine Langan and Tracey Seaward, Producers'),
#  ('2007', 'Actor in a Supporting Role', None, 'Casey Affleck', 'The Assassination of Jesse James by the Coward Robert Ford'),
#  ('2007', 'Actor in a Supporting Role', '1.0', 'Javier Bardem', 'No Country for Old Men'),
#  ('2007', 'Actor in a Supporting Role', None, 'Philip Seymour Hoffman', "Charlie Wilson's War"),
#  ('2007', 'Actor in a Supporting Role', None, 'Hal Holbrook', 'Into the Wild'),
#  ('2007', 'Actor in a Supporting Role', None, 'Tom Wilkinson', 'Michael Clayton'),
#  ('2007', 'Actress in a Supporting Role', None, 'Cate Blanchett', "I'm Not There"),
#  ('2007', 'Actress in a Supporting Role', None, 'Ruby Dee', 'American Gangster'),
#  ('2007', 'Actress in a Supporting Role', None, 'Saoirse Ronan', 'Atonement'),
#  ('2007', 'Actress in a Supporting Role', None, 'Amy Ryan', 'Gone Baby Gone'),
#  ('2007', 'Actress in a Supporting Role', '1.0', 'Tilda Swinton', 'Michael Clayton'),
#  ('2007', 'Best Picture', None, 'Atonement ', 'Tim Bevan, Eric Fellner and Paul Webster, Producers'),
#  ('2007', 'Best Picture', None, 'Juno ', 'Lianne Halfon, Mason Novick and Russell Smith, Producers'),
#  ('2007', 'Best Picture', None, 'Michael Clayton ', 'Sydney Pollack, Jennifer Fox and Kerry Orent, Producers'),
#  ('2007', 'Best Picture', '1.0', 'No Country for Old Men ', 'Scott Rudin, Ethan Coen and Joel Coen, Producers'),
#  ('2007', 'Best Picture', None, 'There Will Be Blood ', 'JoAnne Sellar, Paul Thomas Anderson and Daniel Lupi, Producers'),
#  ('2008', 'Actor in a Supporting Role', None, 'Josh Brolin', 'Milk'),
#  ('2008', 'Actor in a Supporting Role', None, 'Robert Downey Jr.', 'Tropic Thunder'),
#  ('2008', 'Actor in a Supporting Role', None, 'Philip Seymour Hoffman', 'Doubt'),
#  ('2008', 'Actor in a Supporting Role', '1.0', 'Heath Ledger', 'The Dark Knight'),
#  ('2008', 'Actor in a Supporting Role', None, 'Michael Shannon', 'Revolutionary Road'),
#  ('2008', 'Actress in a Supporting Role', None, 'Amy Adams', 'Doubt'),
#  ('2008', 'Actress in a Supporting Role', '1.0', 'Pen+¬lope Cruz', 'Vicky Cristina Barcelona'),
#  ('2008', 'Actress in a Supporting Role', None, 'Viola Davis', 'Doubt'),
#  ('2008', 'Actress in a Supporting Role', None, 'Taraji P. Henson', 'The Curious Case of Benjamin Button'),
#  ('2008', 'Actress in a Supporting Role', None, 'Marisa Tomei', 'The Wrestler'),
#  ('2008', 'Best Picture', None, 'The Curious Case of Benjamin Button ', 'Kathleen Kennedy, Frank Marshall and Ce+ín Chaffin, Producers'),
#  ('2008', 'Best Picture', None, 'Frost/Nixon ', 'Brian Grazer, Ron Howard and Eric Fellner, Producers'),
#  ('2008', 'Best Picture', None, 'Milk ', 'Dan Jinks and Bruce Cohen, Producers'),
#  ('2008', 'Best Picture', None, 'The Reader ', 'Anthony Minghella, Sydney Pollack, Donna Gigliotti and Redmond Morris, Producers'),
#  ('2008', 'Best Picture', '1.0', 'Slumdog Millionaire ', 'Christian Colson, Producer'),
#  ('2009', 'Actor in a Supporting Role', None, 'Matt Damon', 'Invictus'),
#  ('2009', 'Actor in a Supporting Role', None, 'Woody Harrelson', 'The Messenger'),
#  ('2009', 'Actor in a Supporting Role', None, 'Christopher Plummer', 'The Last Station'),
#  ('2009', 'Actor in a Supporting Role', None, 'Stanley Tucci', 'The Lovely Bones'),
#  ('2009', 'Actor in a Supporting Role', '1.0', 'Christoph Waltz', 'Inglourious Basterds'),
#  ('2009', 'Actress in a Supporting Role', None, 'Pen+¬lope Cruz', 'Nine'),
#  ('2009', 'Actress in a Supporting Role', None, 'Vera Farmiga', 'Up in the Air'),
#  ('2009', 'Actress in a Supporting Role', None, 'Maggie Gyllenhaal', 'Crazy Heart'),
#  ('2009', 'Actress in a Supporting Role', None, 'Anna Kendrick', 'Up in the Air'),
#  ('2009', 'Actress in a Supporting Role', '1.0', "Mo'Nique", "Precious: Based on the Novel 'Push' by Sapphire"),
#  ('2009', 'Best Picture', None, 'Avatar ', 'James Cameron and Jon Landau, Producers'),
#  ('2009', 'Best Picture', None, 'The Blind Side ', 'Gil Netter, Andrew A. Kosove and Broderick Johnson, Producers'),
#  ('2009', 'Best Picture', None, 'District 9 ', 'Peter Jackson and Carolynne Cunningham, Producers'),
#  ('2009', 'Best Picture', None, 'An Education ', 'Finola Dwyer and Amanda Posey, Producers'),
#  ('2009', 'Best Picture', '1.0', 'The Hurt Locker ', 'Kathryn Bigelow, Mark Boal, Nicolas Chartier and Greg Shapiro, Producers'),
#  ('2009', 'Best Picture', None, 'Inglourious Basterds ', 'Lawrence Bender, Producer'),
#  ('2009', 'Best Picture', None, "Precious: Based on the Novel 'Push' by Sapphire ", 'Lee Daniels, Sarah Siegel-Magness and Gary Magness, Producers'),
#  ('2009', 'Best Picture', None, 'A Serious Man ', 'Joel Coen and Ethan Coen, Producers'),
#  ('2009', 'Best Picture', None, 'Up ', 'Jonas Rivera, Producer'),
#  ('2009', 'Best Picture', None, 'Up in the Air ', 'Daniel Dubiecki, Ivan Reitman and Jason Reitman, Producers'),
#  ('2010', 'Actor in a Supporting Role', '1.0', 'Christian Bale', 'The Fighter'),
#  ('2010', 'Actor in a Supporting Role', None, 'John Hawkes', "Winter's Bone"),
#  ('2010', 'Actor in a Supporting Role', None, 'Jeremy Renner', 'The Town'),
#  ('2010', 'Actor in a Supporting Role', None, 'Mark Ruffalo', 'The Kids Are All Right'),
#  ('2010', 'Actor in a Supporting Role', None, 'Geoffrey Rush', "The King's Speech"),
#  ('2010', 'Actress in a Supporting Role', None, 'Amy Adams', 'The Fighter'),
#  ('2010', 'Actress in a Supporting Role', None, 'Helena Bonham Carter', "The King's Speech"),
#  ('2010', 'Actress in a Supporting Role', '1.0', 'Melissa Leo', 'The Fighter'),
#  ('2010', 'Actress in a Supporting Role', None, 'Hailee Steinfeld', 'True Grit'),
#  ('2010', 'Actress in a Supporting Role', None, 'Jacki Weaver', 'Animal Kingdom'),
#  ('2010', 'Best Picture', None, 'Black Swan ', 'Mike Medavoy, Brian Oliver and Scott Franklin, Producers'),
#  ('2010', 'Best Picture', None, 'The Fighter ', 'David Hoberman, Todd Lieberman and Mark Wahlberg, Producers'),
#  ...]

# %%
# %%sql
# SELECT
#     award,
#     count(distinct(name)) as count
# FROM oscars
# WHERE award IN ('Special Achievement Award', 'Actor in a Supporting Role', 'Actress in a Supporting Role', 'Best Picture')
# GROUP BY award
# ORDER BY count desc;
# Out:
#  * sqlite:///TMDB-a-4006.db
# Done.
# [('Actor in a Supporting Role', 309),
#  ('Actress in a Supporting Role', 306),
#  ('Best Picture', 298),
#  ('Special Achievement Award', 3)]

# %% [markdown]
# ### Question 13
#
# For all of the entries in the Oscars table before 1934, the year is stored differently than in all the subsequent years. For example, the year would be saved as “1932/1933” instead of just “1933” (the second indicated year).  Which of the following options would be the appropriate code to update this column to have the format of the year be consistent throughout the entire table (second indicated year only shown)?
#
#
# **Options:**
#
# - `UPDATE Oscars SET year = RIGHT(year, -4)`
# - `UPDATE Oscars SET year = SELECT substr(year, -4)`
# - `UPDATE Oscars SET year = substr(year, -4)`
# - `UPDATE Oscars year =  substr(year, 4)`

# %% [markdown]
# ### Question 14
#
# DStv will be having a special week dedicated to the actor Alan Rickman. Which of the following queries would create a new _view_ that shows the titles, release dates, taglines, and overviews of all movies that Alan Rickman has played in?
#
#
#
# **Options:**
#
# - SELECT title, release_date, tagline, overview
# FROM Movies LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id Left JOIN Actors ON Casts.actor_id = Actors.actor_id
# WHERE Actors.actor_name = 'Alan Rickman'
# AS VIEW Alan_Rickman_Movies
#
# - CREATE VIEW Alan_Rickman_Movies AS
# SELECT title, release_date, tagline, overview FROM Movies
# LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id Left JOIN Actors
# ON Casts.actor_id = Actors.actor_id
# WHERE Actors.actor_name = 'Alan Rickman'
#
#
# - CREATE NEW VIEW  Name  = Alan_Rickman_Movies AS SELECT title, release_date, tagline, overview FROM Movies LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id Left JOIN Actors ON Casts.actor_id = Actors.actor_id WHERE Actors.actor_name = 'Alan Rickman'
#
# - VIEW Alan_Rickman_Movies AS SELECT title, release_date, tagline, overview FROM Movies LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id Left JOIN Actors ON Casts.actor_id = Actors.actor_id WHERE Actors.actor_name = 'Alan Rickman'

# %%
# %%sql
#
# CREATE VIEW Alan_Rickman_Movies AS
# SELECT title, release_date, tagline, overview FROM Movies
# LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id Left JOIN Actors ON Casts.actor_id = Actors.actor_id WHERE Actors.actor_name = 'Alan Rickman'
# Out:
#  * sqlite:///TMDB-a-4006.db
# (sqlite3.OperationalError) view Alan_Rickman_Movies already exists
# [SQL: CREATE VIEW Alan_Rickman_Movies AS
# SELECT title, release_date, tagline, overview FROM Movies
# LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id Left JOIN Actors ON Casts.actor_id = Actors.actor_id WHERE Actors.actor_name = 'Alan Rickman']
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ### Question 15
#
# Which of the statements about database normalisation are true?
#
# **Statements:**
#
# i) Database normalisation improves data redundancy, saves on storage space, and fulfils the requirement of records to be uniquely identified.
#
# ii) Database normalisation supports up to the Third Normal Form and removes all data anomalies.
#
# iii) Database normalisation removes inconsistencies that may cause the analysis of our data to be more complicated.
#
# iv) Database normalisation increases data redundancy, saves on storage space, and fulfils the requirement of records to be uniquely identified.
#
# **Options:**
#
#  - (i) and (ii)
#  - (i) and (iii)
#  - (ii) and (iv)
#  - (iii) and (iv)

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
